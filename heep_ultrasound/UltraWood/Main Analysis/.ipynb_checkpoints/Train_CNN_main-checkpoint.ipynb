# %%
import torch
import torch.utils.data
import glob
import random
import numpy as np
import pandas as pd
from torch import nn, optim
from torch.nn import functional as F
import time
from torch.nn.utils import weight_norm

# %%
seed = 1995
random.seed(seed)     # python random generator
np.random.seed(seed)  # numpy random generator

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
Fs = 100000

# %%
train_data_torch = torch.load('../data/databases/train_data_torch_main.pt')
train_targets_torch = torch.load('../data/databases/train_targets_torch_main.pt')

test_data_torch = torch.load('../data/databases/test_data_torch_main.pt')
test_targets_torch = torch.load('../data/databases/test_targets_torch_main.pt')

# %%
print('Dim Train Data: ', train_data_torch.shape)
print('Dim Train Targets: ', train_targets_torch.shape)
print('Dim Test Data: ', test_data_torch.shape)
print('Dim Train Targets: ', test_targets_torch.shape)
# Out:
# Dim Train Data:  torch.Size([15709, 1, 35000])
# Dim Train Targets:  torch.Size([15709])
# Dim Test Data:  torch.Size([3935, 1, 35000])
# Dim Train Targets:  torch.Size([3935])

# %%
numChannels = 1
numClasses = 3

# %%
import matplotlib.pyplot as plt
i = 100

# %%
plt.plot(train_data_torch.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %% [markdown]
# # This is the formula for computing the size of the output of every layer
#
# $$L_{out} = \frac{L_{in}- Kernel_{size}}{stride}+1$$

# %% [markdown]
# # Here there's and example:
# $input size = 1 * 20'000 * 4 $
#
# after the first convolution:
# $output = \frac{20000-5000}{5}+1 = 3001$
# and the channels go from the initial 4 to the specified 32
#
# after the second convolution:
# $output = \frac{3001-2002}{1}+1 = 1000$
# and the channels go from 32 to 64
#
# after the last convolution:
# $output = \frac{1000-1000}{1}+1 = 1$
# and the channels go from 64 to 5 (as the number of classes!!!)

# %%
(35000-5000)/2+1
# Out:
# 15001.0

# %%
(15001-5000)/2+1
# Out:
# 5001.5

# %%
(5001-4500)/2+1
# Out:
# 251.5

# %%
class fastCNN(nn.Module): 
    def __init__(self):
        super(fastCNN, self).__init__()
        self.conv = nn.Conv1d(numChannels, 2, kernel_size=5000, stride=2) 
        self.bn = nn.BatchNorm1d(2) #15001
        self.conv2 = nn.Conv1d(2, 2, kernel_size=5000, stride=2)
        self.bn2 = nn.BatchNorm1d(2) #5001
        self.conv3 = nn.Conv1d(2, 2, kernel_size=4500, stride=2)
        self.bn3 = nn.BatchNorm1d(2) #251
        self.conv4 = nn.Conv1d(2, numClasses, kernel_size=251)
                
    def forward(self, x):
        x = F.relu(self.bn(self.conv(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.conv4(x)
        x = x.view(-1, numClasses)
        return x

# %%
model, criterion = fastCNN(), nn.CrossEntropyLoss()

# %%
def count_parameters(model): return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
count_parameters(model)
# Out:
# 49527

# %%
def compute_nb_errors(model, testing_generator):
    nb_errors=0
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            predicted_classes = outputTest.max(1)[1]
            nb_errors += (predicted_classes != local_labels).long().sum()

    return nb_errors

# %%
if (torch.cuda.is_available()):
    model = model.cuda()

# %%
train_input = train_data_torch.view(train_data_torch.size(0), numChannels, -1).float()
train_target = train_targets_torch.long().view(-1)
test_input = test_data_torch.view(test_data_torch.size(0), numChannels, -1).float()
test_target = test_targets_torch.long().view(-1)

# %%
train_input.shape
# Out:
# torch.Size([15709, 1, 35000])

# %%
train_input = (train_input-torch.mean(train_input,2,keepdim=True))/(4096.0/2)
test_input = (test_input-torch.mean(test_input,2,keepdim=True))/(4096.0/2)

# %%
plt.plot(train_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
plt.plot(test_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
train_input.narrow(0, 0, 2).shape
# Out:
# torch.Size([2, 1, 35000])

# %%
out = model(train_input.narrow(0, 0, 2).cuda())
out.shape
# Out:
# torch.Size([2, 3])

# %%
lr = 3e-3

# %%
optimizer = optim.Adam(model.parameters(), lr = lr)
nb_epochs = 150
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', verbose=True, factor=0.2, patience = 30)

# %%
class errorsTable():
    def __init__(self):
        self.accuracyMatr = np.zeros((numClasses,numClasses))
    def newEntry(self,predictions,groundTruths):
        for pred,tru in zip(predictions,groundTruths):
            #print(pred, tru)
            self.accuracyMatr[pred,tru]+=1
    def getStats(self):
        #print(self.accuracyMatr)
        numEntry = np.sum(self.accuracyMatr,0)
        resultMatr = self.accuracyMatr/numEntry
        return resultMatr

# %%
np.set_printoptions(precision=2, suppress=True)

# %%
batch_size_train = 5000
batch_size_test = 1000

# %%
#torch.backends.cudnn.enabled = False

# %%
training_set = torch.utils.data.TensorDataset(train_input, train_target)
testing_set = torch.utils.data.TensorDataset(test_input, test_target)

# %%
# Generators
training_generator = torch.utils.data.DataLoader(training_set, batch_size=batch_size_train, num_workers=0,
                                                shuffle=True, drop_last=True)
testing_generator = torch.utils.data.DataLoader(testing_set, batch_size=batch_size_test, num_workers=0,
                                                 shuffle=False, drop_last=False)

# %%
loss_train = []
loss_test = []

t = time.time()
for k in range (nb_epochs):
    
    # Create a new error table
    accuracyTRAIN = errorsTable()
    accuracyTEST = errorsTable()
    print('Epoch: ', k)
    model.train()

    lossValue = 0
    for local_batch, local_labels in training_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()       
        model.zero_grad()
        output = model(local_batch)
        accuracyTRAIN.newEntry(output.max(1)[1], local_labels)
        loss = criterion(output, local_labels)
        lossValue += loss.item()*local_batch.size(0)
        loss.backward()
        optimizer.step()
    scheduler.step(lossValue/train_input.size(0))
    print('Loss is ', lossValue/train_input.size(0))
    loss_train.append(lossValue/train_input.size(0))    
    ################################################################    
    model.eval()
    lossValue = 0 
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
            lossTest = criterion(outputTest, local_labels)
            lossValue += lossTest.item()*local_batch.size(0)
    print('Loss TEST is ', lossValue/test_input.size(0))
    loss_test.append(lossValue/test_input.size(0))
    print("")
    print("The accuracy in TEST is: ")
    print("  1      2      3   ")
    print(accuracyTEST.getStats())
    print("The accuracy in TRAIN is: ")
    print("  1      2      3   ")
    print(accuracyTRAIN.getStats())
    print("----------------------")
    if k%10 == 0:
        #nb_test_errors = compute_nb_errors(model, test_input, test_target, batch_size_test)

        #print(k, ': Test accuracy Net {:0.2f}%% {:d}/{:d}'.format(100-(100 * nb_test_errors) / test_input.size(0),
                                                     #nb_test_errors, test_input.size(0)))
        

        #nb_train_errors = compute_nb_errors(model, train_input, train_target, batch_size_train)

        #print(k, ': Train accuracy Net {:0.2f}%% {:d}/{:d}'.format(100-(100 * nb_train_errors) / train_input.size(0),
                                                          #nb_train_errors, train_input.size(0)))
        print("Hey! Ten epochs are passed! We are getting older")
        
        


nb_test_errors = compute_nb_errors(model, testing_generator)  
print('Final Test error Net {:0.2f}% {:d}/{:d}'.format((100 * nb_test_errors) / test_input.size(0),
                                                  nb_test_errors, test_input.size(0)))

elapsed = time.time() - t
print(elapsed)
# Out:
# Epoch:  0
# Loss is  1.2968835828260126
# Loss TEST is  1.6333226620620815
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.52 0.42 0.6 ]
#  [0.14 0.22 0.06]
#  [0.33 0.36 0.34]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  1
# Loss is  0.9949523826340259
# Loss TEST is  2.7368315414181206
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.67 0.66 0.68]
#  [0.15 0.17 0.  ]
#  [0.18 0.17 0.32]]
# ----------------------
# Epoch:  2
# Loss is  0.9415301878058149
# Loss TEST is  1.7789210946768939
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.5  0.01]
#  [0.   0.   0.  ]
#  [0.22 0.5  0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   1.   0.97]
#  [0.   0.   0.  ]
#  [0.   0.   0.03]]
# ----------------------
# Epoch:  3
# Loss is  0.8687453431140323
# Loss TEST is  1.924053686433099
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.49 0.  ]
#  [0.   0.   0.  ]
#  [0.22 0.51 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.82 0.42 0.07]
#  [0.   0.25 0.  ]
#  [0.18 0.33 0.93]]
# ----------------------
# Epoch:  4
# Loss is  0.7858746632619639
# Loss TEST is  2.605888149865549
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.88 0.2 ]
#  [0.   0.   0.  ]
#  [0.12 0.12 0.8 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.87 0.37 0.19]
#  [0.01 0.41 0.  ]
#  [0.12 0.21 0.81]]
# ----------------------
# Epoch:  5
# Loss is  0.7279541371196359
# Loss TEST is  3.2221946093943705
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.51 0.06]
#  [0.   0.   0.  ]
#  [0.15 0.49 0.94]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.88 0.67 0.37]
#  [0.   0.22 0.  ]
#  [0.12 0.11 0.63]]
# ----------------------
# Epoch:  6
# Loss is  0.6757277915430552
# Loss TEST is  3.4413417582382393
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.5  0.03]
#  [0.   0.   0.  ]
#  [0.17 0.5  0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.86 0.21 0.14]
#  [0.03 0.42 0.  ]
#  [0.12 0.37 0.86]]
# ----------------------
# Epoch:  7
# Loss is  0.6353911098968567
# Loss TEST is  3.5213811330146982
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.83 0.17]
#  [0.   0.   0.  ]
#  [0.12 0.17 0.83]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.8  0.3  0.18]
#  [0.08 0.51 0.  ]
#  [0.12 0.19 0.82]]
# ----------------------
# Epoch:  8
# Loss is  0.6098694019401405
# Loss TEST is  3.561795605230589
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.49 0.  ]
#  [0.   0.   0.  ]
#  [0.22 0.51 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.25 0.18]
#  [0.1  0.52 0.  ]
#  [0.12 0.23 0.82]]
# ----------------------
# Epoch:  9
# Loss is  0.5855563679660586
# Loss TEST is  3.2109925831931974
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.6  0.16]
#  [0.   0.   0.  ]
#  [0.12 0.4  0.84]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.8  0.14 0.17]
#  [0.09 0.49 0.  ]
#  [0.12 0.37 0.83]]
# ----------------------
# Epoch:  10
# Loss is  0.5635645533892023
# Loss TEST is  2.8763456128471385
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.49 0.  ]
#  [0.   0.   0.  ]
#  [0.22 0.51 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.8  0.33 0.18]
#  [0.08 0.5  0.01]
#  [0.12 0.17 0.81]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  11
# Loss is  0.5458862118736489
# Loss TEST is  2.479626638982847
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.53 0.07]
#  [0.   0.   0.  ]
#  [0.15 0.47 0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.12 0.1 ]
#  [0.1  0.62 0.03]
#  [0.12 0.26 0.87]]
# ----------------------
# Epoch:  12
# Loss is  0.5242299271674074
# Loss TEST is  2.238094869906407
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.5  0.01]
#  [0.   0.   0.  ]
#  [0.21 0.5  0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.79 0.27 0.17]
#  [0.09 0.54 0.03]
#  [0.12 0.19 0.8 ]]
# ----------------------
# Epoch:  13
# Loss is  0.5060368320626087
# Loss TEST is  1.9650907408744287
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.55 0.11]
#  [0.   0.   0.  ]
#  [0.13 0.45 0.89]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.11 0.08]
#  [0.1  0.63 0.03]
#  [0.12 0.26 0.9 ]]
# ----------------------
# Epoch:  14
# Loss is  0.48791201537035916
# Loss TEST is  1.7049822194366853
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.51 0.01]
#  [0.   0.   0.  ]
#  [0.21 0.49 0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.16 0.14]
#  [0.1  0.69 0.03]
#  [0.12 0.15 0.83]]
# ----------------------
# Epoch:  15
# Loss is  0.46722567683227256
# Loss TEST is  1.3817455024379182
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.47 0.03]
#  [0.   0.07 0.  ]
#  [0.15 0.46 0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.12 0.05]
#  [0.1  0.7  0.03]
#  [0.12 0.18 0.92]]
# ----------------------
# Epoch:  16
# Loss is  0.4453730845756417
# Loss TEST is  1.1977707734035643
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.37 0.  ]
#  [0.   0.18 0.  ]
#  [0.17 0.46 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.17 0.06]
#  [0.1  0.68 0.03]
#  [0.12 0.15 0.91]]
# ----------------------
# Epoch:  17
# Loss is  0.42454306541587117
# Loss TEST is  1.0323797446051957
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.37 0.  ]
#  [0.   0.18 0.  ]
#  [0.16 0.46 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.17 0.04]
#  [0.1  0.71 0.04]
#  [0.12 0.12 0.93]]
# ----------------------
# Epoch:  18
# Loss is  0.3972437852389247
# Loss TEST is  0.8772628233594089
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.35 0.  ]
#  [0.   0.19 0.  ]
#  [0.12 0.46 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.14 0.02]
#  [0.1  0.72 0.01]
#  [0.12 0.14 0.96]]
# ----------------------
# Epoch:  19
# Loss is  0.3758295578446347
# Loss TEST is  0.8398122013164294
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.29 0.  ]
#  [0.05 0.25 0.  ]
#  [0.12 0.46 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.18 0.02]
#  [0.1  0.72 0.02]
#  [0.12 0.1  0.95]]
# ----------------------
# Epoch:  20
# Loss is  0.3507338643066447
# Loss TEST is  0.6966838263344431
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.19 0.  ]
#  [0.07 0.35 0.  ]
#  [0.12 0.46 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.2  0.01]
#  [0.1  0.73 0.03]
#  [0.12 0.07 0.96]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  21
# Loss is  0.3279822413322919
# Loss TEST is  0.6044797033753146
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.07 0.  ]
#  [0.07 0.47 0.  ]
#  [0.12 0.46 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.78 0.2  0.01]
#  [0.1  0.73 0.01]
#  [0.12 0.07 0.99]]
# ----------------------
# Epoch:  22
# Loss is  0.3059908536140859
# Loss TEST is  0.5112996953225953
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.   0.  ]
#  [0.1  0.59 0.  ]
#  [0.12 0.41 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.8  0.04 0.01]
#  [0.1  0.92 0.01]
#  [0.1  0.04 0.98]]
# ----------------------
# Epoch:  23
# Loss is  0.29098810006147185
# Loss TEST is  0.5520571550541336
#
# The accuracy in TEST is:
#   1      2      3
# [[0.65 0.   0.  ]
#  [0.11 0.59 0.  ]
#  [0.25 0.41 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.83 0.05 0.02]
#  [0.1  0.9  0.01]
#  [0.07 0.05 0.97]]
# ----------------------
# Epoch:  24
# Loss is  0.26609525923984223
# Loss TEST is  0.4782546399660607
#
# The accuracy in TEST is:
#   1      2      3
# [[0.76 0.04 0.  ]
#  [0.11 0.62 0.  ]
#  [0.13 0.34 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.84 0.   0.02]
#  [0.1  0.97 0.01]
#  [0.06 0.03 0.97]]
# ----------------------
# Epoch:  25
# Loss is  0.24579657949931724
# Loss TEST is  0.46670617148034
#
# The accuracy in TEST is:
#   1      2      3
# [[0.75 0.   0.  ]
#  [0.11 0.74 0.  ]
#  [0.14 0.26 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.84 0.   0.01]
#  [0.1  0.95 0.01]
#  [0.06 0.04 0.98]]
# ----------------------
# Epoch:  26
# Loss is  0.23259815746143217
# Loss TEST is  0.37258512256939197
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.01 0.  ]
#  [0.11 0.77 0.  ]
#  [0.12 0.23 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.86 0.01 0.01]
#  [0.1  0.94 0.  ]
#  [0.03 0.05 0.99]]
# ----------------------
# Epoch:  27
# Loss is  0.20691234132517938
# Loss TEST is  0.33365970640295345
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.   0.  ]
#  [0.11 0.78 0.  ]
#  [0.12 0.22 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.88 0.05 0.01]
#  [0.09 0.92 0.01]
#  [0.03 0.02 0.98]]
# ----------------------
# Epoch:  28
# Loss is  0.19120288533403748
# Loss TEST is  0.35080859214635485
#
# The accuracy in TEST is:
#   1      2      3
# [[0.77 0.   0.  ]
#  [0.11 0.81 0.  ]
#  [0.12 0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.89 0.03 0.02]
#  [0.09 0.96 0.01]
#  [0.02 0.02 0.98]]
# ----------------------
# Epoch:  29
# Loss is  0.20829572855337275
# Loss TEST is  0.35603383961672097
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.31 0.03]
#  [0.07 0.56 0.  ]
#  [0.11 0.13 0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.89 0.02 0.02]
#  [0.08 0.9  0.  ]
#  [0.03 0.07 0.98]]
# ----------------------
# Epoch:  30
# Loss is  0.5517168069782775
# Loss TEST is  4.06319329153931
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.88 0.53]
#  [0.   0.   0.  ]
#  [0.12 0.12 0.47]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.72 0.24 0.11]
#  [0.16 0.67 0.04]
#  [0.12 0.08 0.84]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  31
# Loss is  0.46850569312399004
# Loss TEST is  4.495170943827157
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.42 0.17]
#  [0.   0.   0.  ]
#  [0.22 0.58 0.83]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.76 0.14 0.2 ]
#  [0.2  0.81 0.  ]
#  [0.05 0.05 0.79]]
# ----------------------
# Epoch:  32
# Loss is  0.3698874482890576
# Loss TEST is  8.136951961143954
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.88 0.99]
#  [0.   0.   0.  ]
#  [0.   0.12 0.01]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.84 0.31 0.08]
#  [0.11 0.55 0.  ]
#  [0.05 0.14 0.92]]
# ----------------------
# Epoch:  33
# Loss is  0.2901664445884239
# Loss TEST is  4.1378961447082
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.57 0.26]
#  [0.   0.   0.  ]
#  [0.22 0.43 0.74]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.2  0.09]
#  [0.05 0.78 0.02]
#  [0.01 0.02 0.89]]
# ----------------------
# Epoch:  34
# Loss is  0.2863913446283483
# Loss TEST is  3.26620073489646
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.49 0.17]
#  [0.   0.   0.  ]
#  [0.22 0.51 0.83]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.83 0.07 0.  ]
#  [0.06 0.84 0.  ]
#  [0.11 0.1  1.  ]]
# ----------------------
# Epoch:  35
# Loss is  0.24745122117114118
# Loss TEST is  2.747363890957157
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.47 0.11]
#  [0.   0.   0.  ]
#  [0.22 0.53 0.89]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.9  0.35 0.  ]
#  [0.06 0.64 0.01]
#  [0.04 0.01 0.99]]
# ----------------------
# Epoch:  36
# Loss is  0.21161436010146173
# Loss TEST is  2.1864114441776357
#
# The accuracy in TEST is:
#   1      2      3
# [[0.57 0.37 0.  ]
#  [0.   0.15 0.  ]
#  [0.43 0.48 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.9  0.12 0.  ]
#  [0.09 0.87 0.01]
#  [0.01 0.   0.99]]
# ----------------------
# Epoch:  37
# Loss is  0.19617488272087344
# Loss TEST is  1.359360715650005
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.35 0.  ]
#  [0.   0.19 0.  ]
#  [0.17 0.46 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.97 0.15 0.  ]
#  [0.   0.8  0.  ]
#  [0.03 0.05 1.  ]]
# ----------------------
# Epoch:  38
# Loss is  0.17138229676757263
# Loss TEST is  0.8373250567015222
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.2  0.03]
#  [0.05 0.41 0.  ]
#  [0.12 0.39 0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.98 0.1  0.  ]
#  [0.   0.89 0.  ]
#  [0.02 0.01 1.  ]]
# ----------------------
# Epoch:  39
# Loss is  0.16428923874750076
# Loss TEST is  0.41404190068896457
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.08 0.  ]
#  [0.   0.69 0.  ]
#  [0.12 0.23 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.95 0.03 0.  ]
#  [0.03 0.97 0.  ]
#  [0.02 0.   1.  ]]
# ----------------------
# Epoch:  40
# Loss is  0.1477996464013613
# Loss TEST is  0.35420051242936085
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.08 0.  ]
#  [0.   0.7  0.  ]
#  [0.12 0.22 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.98 0.05 0.  ]
#  [0.   0.89 0.  ]
#  [0.02 0.05 1.  ]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  41
# Loss is  0.12870583685860915
# Loss TEST is  0.257665545541173
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.05 0.  ]
#  [0.   0.78 0.  ]
#  [0.12 0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.04 0.  ]
#  [0.   0.95 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  42
# Loss is  0.11976670529068491
# Loss TEST is  0.172933460238095
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.16 0.  ]
#  [0.   0.84 0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.02 0.  ]
#  [0.   0.98 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  43
# Loss is  0.10953224031980902
# Loss TEST is  0.2626208669045677
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.22 0.12]
#  [0.   0.78 0.07]
#  [0.   0.   0.81]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.05 0.  ]
#  [0.   0.94 0.  ]
#  [0.   0.01 1.  ]]
# ----------------------
# Epoch:  44
# Loss is  0.09927173697126611
# Loss TEST is  0.2553737981498166
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.09 0.09]
#  [0.01 0.91 0.13]
#  [0.   0.   0.78]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.02 0.  ]
#  [0.   0.97 0.  ]
#  [0.01 0.01 1.  ]]
# ----------------------
# Epoch:  45
# Loss is  0.08987261540749047
# Loss TEST is  0.29969350673646455
#
# The accuracy in TEST is:
#   1      2      3
# [[0.97 0.17 0.18]
#  [0.03 0.83 0.07]
#  [0.   0.   0.74]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  46
# Loss is  0.08368405426730098
# Loss TEST is  0.38027239849334143
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.16 0.18]
#  [0.13 0.84 0.17]
#  [0.   0.   0.66]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.06 0.  ]
#  [0.   0.93 0.  ]
#  [0.   0.01 1.  ]]
# ----------------------
# Epoch:  47
# Loss is  0.07735642020741368
# Loss TEST is  0.4568373979728437
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.09 0.17]
#  [0.15 0.91 0.23]
#  [0.   0.   0.6 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.  ]
#  [0.   0.01 1.  ]]
# ----------------------
# Epoch:  48
# Loss is  0.07121265788257096
# Loss TEST is  0.4346266507799471
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.17 0.22]
#  [0.15 0.83 0.15]
#  [0.   0.   0.63]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.02 0.  ]
#  [0.   0.98 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  49
# Loss is  0.06576070537223527
# Loss TEST is  0.30288501809028084
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.07 0.17]
#  [0.15 0.93 0.12]
#  [0.   0.   0.71]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.98 0.  ]
#  [0.   0.01 1.  ]]
# ----------------------
# Epoch:  50
# Loss is  0.060828686855153344
# Loss TEST is  0.37619186860179055
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.08 0.19]
#  [0.17 0.92 0.16]
#  [0.   0.   0.65]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  51
# Loss is  0.05658176580030281
# Loss TEST is  0.5118245012878311
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.08 0.21]
#  [0.19 0.92 0.19]
#  [0.   0.   0.6 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   0.99 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  52
# Loss is  0.052898126234641865
# Loss TEST is  0.5212415988442253
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.05 0.21]
#  [0.19 0.95 0.19]
#  [0.   0.   0.6 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  53
# Loss is  0.04908824203744245
# Loss TEST is  0.7189359328646824
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.08 0.25]
#  [0.21 0.92 0.24]
#  [0.   0.   0.51]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  54
# Loss is  0.0453462366656667
# Loss TEST is  0.8511347398067217
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.09 0.25]
#  [0.22 0.91 0.3 ]
#  [0.   0.   0.45]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  55
# Loss is  0.042457296449288626
# Loss TEST is  0.8499704061651169
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.1  0.26]
#  [0.21 0.9  0.29]
#  [0.   0.   0.46]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  56
# Loss is  0.040448248268759784
# Loss TEST is  0.7496957677443721
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8  0.09 0.24]
#  [0.2  0.91 0.25]
#  [0.   0.   0.51]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  57
# Loss is  0.03757126483746341
# Loss TEST is  0.9441576800776558
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.1  0.26]
#  [0.22 0.9  0.32]
#  [0.   0.   0.42]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  58
# Loss is  0.03486405613428616
# Loss TEST is  0.8926464661558217
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.1  0.26]
#  [0.21 0.9  0.3 ]
#  [0.   0.   0.44]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  59
# Loss is  0.03275322943719068
# Loss TEST is  0.99100363845292
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.11 0.26]
#  [0.22 0.89 0.33]
#  [0.   0.   0.41]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  60
# Loss is  0.03037120046807744
# Loss TEST is  1.2047065311647582
#
# The accuracy in TEST is:
#   1      2      3
# [[0.77 0.11 0.28]
#  [0.23 0.89 0.44]
#  [0.   0.   0.29]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  61
# Loss is  0.028537464320936623
# Loss TEST is  1.3969400598557506
#
# The accuracy in TEST is:
#   1      2      3
# [[0.77 0.12 0.3 ]
#  [0.23 0.88 0.5 ]
#  [0.   0.   0.19]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  62
# Loss is  0.026790540551796277
# Loss TEST is  1.4259935387207865
#
# The accuracy in TEST is:
#   1      2      3
# [[0.76 0.11 0.29]
#  [0.24 0.89 0.53]
#  [0.   0.   0.19]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  63
# Loss is  0.02510503996385336
# Loss TEST is  1.401865283597682
#
# The accuracy in TEST is:
#   1      2      3
# [[0.76 0.11 0.3 ]
#  [0.24 0.89 0.5 ]
#  [0.   0.   0.21]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  64
# Loss is  0.023358607675020075
# Loss TEST is  1.403953376991776
#
# The accuracy in TEST is:
#   1      2      3
# [[0.77 0.11 0.3 ]
#  [0.23 0.89 0.5 ]
#  [0.   0.   0.21]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  65
# Loss is  0.022365671018533016
# Loss TEST is  1.5041446619142873
#
# The accuracy in TEST is:
#   1      2      3
# [[0.75 0.11 0.29]
#  [0.25 0.89 0.54]
#  [0.   0.   0.17]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  66
# Loss is  0.02042144606692292
# Loss TEST is  1.4545680751037113
#
# The accuracy in TEST is:
#   1      2      3
# [[0.76 0.12 0.3 ]
#  [0.24 0.88 0.5 ]
#  [0.   0.   0.19]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  67
# Loss is  0.019153666982706003
# Loss TEST is  1.4649135571119898
#
# The accuracy in TEST is:
#   1      2      3
# [[0.75 0.11 0.3 ]
#  [0.25 0.89 0.51]
#  [0.   0.   0.19]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  68
# Loss is  0.017939024093278733
# Loss TEST is  1.719789997140819
#
# The accuracy in TEST is:
#   1      2      3
# [[0.69 0.14 0.31]
#  [0.31 0.86 0.57]
#  [0.   0.   0.12]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  69
# Loss is  0.017066191232358485
# Loss TEST is  1.750285314029175
#
# The accuracy in TEST is:
#   1      2      3
# [[0.69 0.15 0.32]
#  [0.31 0.85 0.56]
#  [0.   0.   0.12]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  70
# Loss is  0.01572748543338307
# Loss TEST is  1.4925379185088858
#
# The accuracy in TEST is:
#   1      2      3
# [[0.74 0.11 0.29]
#  [0.26 0.89 0.53]
#  [0.   0.   0.18]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  71
# Loss is  0.014906156625774393
# Loss TEST is  1.7349522365245311
#
# The accuracy in TEST is:
#   1      2      3
# [[0.68 0.15 0.32]
#  [0.32 0.85 0.55]
#  [0.   0.   0.13]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  72
# Loss is  0.013841649112968382
# Loss TEST is  1.904983599425271
#
# The accuracy in TEST is:
#   1      2      3
# [[0.67 0.14 0.31]
#  [0.33 0.86 0.58]
#  [0.   0.   0.11]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  73
# Loss is  0.012881804969773817
# Loss TEST is  1.657162911101248
#
# The accuracy in TEST is:
#   1      2      3
# [[0.71 0.12 0.3 ]
#  [0.29 0.88 0.56]
#  [0.   0.   0.14]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  74
# Loss is  0.012554635600112125
# Loss TEST is  1.6560646227384612
#
# The accuracy in TEST is:
#   1      2      3
# [[0.69 0.13 0.31]
#  [0.31 0.87 0.53]
#  [0.   0.   0.16]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  75
# Loss is  0.011313947515136622
# Loss TEST is  1.6658894683990575
#
# The accuracy in TEST is:
#   1      2      3
# [[0.68 0.11 0.3 ]
#  [0.32 0.89 0.56]
#  [0.   0.   0.15]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  76
# Loss is  0.01052010277244316
# Loss TEST is  1.9523185780875414
#
# The accuracy in TEST is:
#   1      2      3
# [[0.67 0.16 0.33]
#  [0.33 0.84 0.56]
#  [0.   0.   0.11]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  77
# Loss is  0.009942574579370903
# Loss TEST is  1.8998012062555043
#
# The accuracy in TEST is:
#   1      2      3
# [[0.67 0.14 0.31]
#  [0.33 0.86 0.58]
#  [0.   0.   0.11]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  78
# Loss is  0.009340625921488035
# Loss TEST is  1.7077197661999675
#
# The accuracy in TEST is:
#   1      2      3
# [[0.67 0.12 0.3 ]
#  [0.33 0.88 0.56]
#  [0.   0.   0.14]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  79
# Loss is  0.008653578841657412
# Loss TEST is  1.7703875639538602
#
# The accuracy in TEST is:
#   1      2      3
# [[0.67 0.13 0.31]
#  [0.33 0.87 0.56]
#  [0.   0.   0.13]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  80
# Loss is  0.008102413320254532
# Loss TEST is  1.7864019957097694
#
# The accuracy in TEST is:
#   1      2      3
# [[0.67 0.11 0.3 ]
#  [0.33 0.89 0.59]
#  [0.   0.   0.12]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  81
# Loss is  0.007730815968698498
# Loss TEST is  1.7138835593130264
#
# The accuracy in TEST is:
#   1      2      3
# [[0.67 0.11 0.31]
#  [0.33 0.89 0.56]
#  [0.   0.   0.13]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  82
# Loss is  0.007187876072772418
# Loss TEST is  1.6223381969798474
#
# The accuracy in TEST is:
#   1      2      3
# [[0.68 0.11 0.3 ]
#  [0.32 0.89 0.55]
#  [0.   0.   0.15]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  83
# Loss is  0.006692843797814498
# Loss TEST is  1.4345405009377563
#
# The accuracy in TEST is:
#   1      2      3
# [[0.71 0.11 0.28]
#  [0.29 0.89 0.52]
#  [0.   0.   0.21]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  84
# Loss is  0.006296218448945253
# Loss TEST is  1.6135076799416936
#
# The accuracy in TEST is:
#   1      2      3
# [[0.68 0.11 0.31]
#  [0.32 0.89 0.54]
#  [0.   0.   0.16]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  85
# Loss is  0.005950162510801237
# Loss TEST is  1.6852845409470865
#
# The accuracy in TEST is:
#   1      2      3
# [[0.67 0.11 0.3 ]
#  [0.33 0.89 0.57]
#  [0.   0.   0.14]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  86
# Loss is  0.005510997881350325
# Loss TEST is  1.4776007043058113
#
# The accuracy in TEST is:
#   1      2      3
# [[0.69 0.11 0.3 ]
#  [0.31 0.89 0.51]
#  [0.   0.   0.19]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  87
# Loss is  0.005161606961786197
# Loss TEST is  1.5205138897501984
#
# The accuracy in TEST is:
#   1      2      3
# [[0.69 0.11 0.3 ]
#  [0.31 0.89 0.51]
#  [0.   0.   0.18]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  88
# Loss is  0.004980785042868967
# Loss TEST is  1.5251499823421202
#
# The accuracy in TEST is:
#   1      2      3
# [[0.68 0.11 0.28]
#  [0.32 0.89 0.55]
#  [0.   0.   0.17]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  89
# Loss is  0.004567413199146348
# Loss TEST is  1.1870267774431649
#
# The accuracy in TEST is:
#   1      2      3
# [[0.76 0.11 0.28]
#  [0.24 0.89 0.45]
#  [0.   0.   0.28]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  90
# Loss is  0.004324416057090194
# Loss TEST is  1.1004109423527118
#
# The accuracy in TEST is:
#   1      2      3
# [[0.77 0.1  0.26]
#  [0.23 0.9  0.42]
#  [0.   0.   0.32]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  91
# Loss is  0.003999909959333662
# Loss TEST is  1.394154853560267
#
# The accuracy in TEST is:
#   1      2      3
# [[0.7  0.11 0.26]
#  [0.3  0.89 0.51]
#  [0.   0.   0.22]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  92
# Loss is  0.0038310042887478375
# Loss TEST is  1.1480039714100703
#
# The accuracy in TEST is:
#   1      2      3
# [[0.74 0.1  0.26]
#  [0.26 0.9  0.45]
#  [0.   0.   0.29]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  93
# Loss is  0.0037743900111398645
# Loss TEST is  0.7258027660195376
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.07 0.2 ]
#  [0.17 0.93 0.29]
#  [0.   0.   0.51]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  94
# Loss is  0.0033763263857628737
# Loss TEST is  0.9995942909502468
#
# The accuracy in TEST is:
#   1      2      3
# [[0.76 0.08 0.23]
#  [0.24 0.92 0.41]
#  [0.   0.   0.36]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  95
# Loss is  0.003185753636875548
# Loss TEST is  1.0986897690929331
#
# The accuracy in TEST is:
#   1      2      3
# [[0.73 0.09 0.24]
#  [0.27 0.91 0.45]
#  [0.   0.   0.32]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  96
# Loss is  0.002997755231007908
# Loss TEST is  0.7030730601944494
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.07 0.2 ]
#  [0.17 0.93 0.29]
#  [0.   0.   0.51]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  97
# Loss is  0.002808818773613318
# Loss TEST is  0.46481531184389147
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.02 0.17]
#  [0.15 0.98 0.22]
#  [0.   0.   0.61]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  98
# Loss is  0.002657886149533777
# Loss TEST is  0.5510461193330709
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.03 0.18]
#  [0.15 0.97 0.25]
#  [0.   0.   0.57]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  99
# Loss is  0.002499088061963611
# Loss TEST is  0.7255912752587732
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.07 0.2 ]
#  [0.18 0.93 0.31]
#  [0.   0.   0.49]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  100
# Loss is  0.0024150587875414746
# Loss TEST is  0.5950619038360092
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.04 0.19]
#  [0.15 0.96 0.27]
#  [0.   0.   0.54]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  101
# Loss is  0.0022237198421983795
# Loss TEST is  0.3493940234184265
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.   0.15]
#  [0.13 1.   0.18]
#  [0.   0.   0.66]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  102
# Loss is  0.002156922836666522
# Loss TEST is  0.3256901348864108
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.   0.15]
#  [0.13 1.   0.17]
#  [0.   0.   0.68]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  103
# Loss is  0.002081138307431561
# Loss TEST is  0.5820596443046608
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.03 0.19]
#  [0.15 0.97 0.26]
#  [0.   0.   0.55]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  104
# Loss is  0.0019394765937701698
# Loss TEST is  0.46842654475414464
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.   0.17]
#  [0.13 1.   0.23]
#  [0.   0.   0.6 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  105
# Loss is  0.001799190943450394
# Loss TEST is  0.22766573248097371
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.   0.1 ]
#  [0.13 1.   0.08]
#  [0.   0.   0.82]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  106
# Loss is  0.00172440208424943
# Loss TEST is  0.18785616015161008
#
# The accuracy in TEST is:
#   1      2      3
# [[0.89 0.   0.08]
#  [0.11 1.   0.05]
#  [0.   0.   0.87]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  107
# Loss is  0.0016420528617424235
# Loss TEST is  0.27691262214429196
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.   0.13]
#  [0.13 1.   0.14]
#  [0.   0.   0.73]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  108
# Loss is  0.001564283884428093
# Loss TEST is  0.2529841903431443
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.   0.12]
#  [0.13 1.   0.11]
#  [0.   0.   0.77]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  109
# Loss is  0.0014876235538860145
# Loss TEST is  0.15641616799855626
#
# The accuracy in TEST is:
#   1      2      3
# [[0.9  0.   0.05]
#  [0.1  1.   0.02]
#  [0.   0.   0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  110
# Loss is  0.0014018891792460062
# Loss TEST is  0.11783753473695079
#
# The accuracy in TEST is:
#   1      2      3
# [[0.93 0.   0.03]
#  [0.07 1.   0.01]
#  [0.   0.   0.95]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  111
# Loss is  0.0013479919014115012
# Loss TEST is  0.11153784162321115
#
# The accuracy in TEST is:
#   1      2      3
# [[0.95 0.   0.03]
#  [0.05 1.   0.01]
#  [0.   0.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  112
# Loss is  0.0012841292897243953
# Loss TEST is  0.09736970902019414
#
# The accuracy in TEST is:
#   1      2      3
# [[0.97 0.   0.02]
#  [0.03 1.   0.01]
#  [0.   0.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  113
# Loss is  0.001249713440508635
# Loss TEST is  0.09419015189100251
#
# The accuracy in TEST is:
#   1      2      3
# [[0.97 0.   0.02]
#  [0.03 1.   0.01]
#  [0.   0.   0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  114
# Loss is  0.0011715241630493292
# Loss TEST is  0.05763757679956993
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  115
# Loss is  0.001120480650203412
# Loss TEST is  0.05516508940649911
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  116
# Loss is  0.0010816886475871405
# Loss TEST is  0.059237422935162896
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  117
# Loss is  0.0010425047650155434
# Loss TEST is  0.04126077701764837
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  118
# Loss is  0.0010144646351901948
# Loss TEST is  0.0286021113840643
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.  ]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  119
# Loss is  0.0009733079764554469
# Loss TEST is  0.028803988585894717
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.  ]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  120
# Loss is  0.0009151981928965552
# Loss TEST is  0.02772462055124958
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.  ]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  121
# Loss is  0.0008916947886905532
# Loss TEST is  0.020641969557108387
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.  ]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  122
# Loss is  0.0008691802736910309
# Loss TEST is  0.018949539807720968
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.  ]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  123
# Loss is  0.0008230188640234229
# Loss TEST is  0.014175619566730274
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  124
# Loss is  0.0007916347487283068
# Loss TEST is  0.01034526001387471
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  125
# Loss is  0.0007708123280971557
# Loss TEST is  0.010557955030938836
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  126
# Loss is  0.000756745149402031
# Loss TEST is  0.009397147307965285
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  127
# Loss is  0.0007218682594956375
# Loss TEST is  0.006309937341363563
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  128
# Loss is  0.0006980343362652878
# Loss TEST is  0.005305848290594685
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  129
# Loss is  0.0006748374773382579
# Loss TEST is  0.005263342104350445
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  130
# Loss is  0.0006548105996950832
# Loss TEST is  0.005251156821790159
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  131
# Loss is  0.0006409088843074949
# Loss TEST is  0.004245223243468769
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  132
# Loss is  0.0006190887186350192
# Loss TEST is  0.003883557378467092
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  133
# Loss is  0.000617152292153806
# Loss TEST is  0.003807030811082226
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  134
# Loss is  0.0005801563010139532
# Loss TEST is  0.0024588927147339607
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  135
# Loss is  0.0005820969701440775
# Loss TEST is  0.0015279073879096699
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  136
# Loss is  0.0005466080457102551
# Loss TEST is  0.001842401392998711
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  137
# Loss is  0.0005425767325900234
# Loss TEST is  0.0025711038727975976
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  138
# Loss is  0.0005210230571443536
# Loss TEST is  0.002223595830681704
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  139
# Loss is  0.000515465891091035
# Loss TEST is  0.0017729970959951247
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  140
# Loss is  0.0004948686458086466
# Loss TEST is  0.001348672559608503
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  141
# Loss is  0.0004824111540480197
# Loss TEST is  0.0013441054854279307
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  142
# Loss is  0.00047561534757142106
# Loss TEST is  0.0015437872152156617
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  143
# Loss is  0.0004588673890968081
# Loss TEST is  0.0017145932908702447
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  144
# Loss is  0.00044810208433880826
# Loss TEST is  0.001628389592096683
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  145
# Loss is  0.00043631869205693134
# Loss TEST is  0.0011907052373711204
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  146
# Loss is  0.0004266978927915663
# Loss TEST is  0.0010181278970848124
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  147
# Loss is  0.0004134561594221588
# Loss TEST is  0.001177032947439104
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  148
# Loss is  0.00040627000145545373
# Loss TEST is  0.0013858495987809749
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  149
# Loss is  0.00039349742353747915
# Loss TEST is  0.0012114318950827148
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Final Test error Net 0.00% 0/3935
# 9720.91540646553

# %%
accuracyTEST = errorsTable()

model.eval()
lossValue = 0 
with torch.set_grad_enabled(False):
    for local_batch, local_labels in testing_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
        outputTest = model(local_batch)
        accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
        lossTest = criterion(outputTest, local_labels)
        lossValue += lossTest.item()*local_batch.size(0)
print('Loss TEST is ', lossValue/test_input.size(0))

print("")
print("The accuracy in TEST is: ")
print("  1      2      3   ")
print(accuracyTEST.getStats())
# Out:
# Loss TEST is  0.0012114318950827148
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
plt.figure()
plt.plot(np.array(loss_test)/max(loss_test))
plt.plot(np.array(loss_train)/max(loss_train))

# %%
torch.save(model, '../Models/model_main')
