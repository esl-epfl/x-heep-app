# %%
import torch
import torch.utils.data
import glob
import random
import numpy as np
import pandas as pd
from torch import nn, optim
from torch.nn import functional as F
import time
from torch.nn.utils import weight_norm

# %%
seed = 1995
random.seed(seed)     # python random generator
np.random.seed(seed)  # numpy random generator

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
Fs = 100000

# %%
train_data_torch = torch.load('../data/databases/train_data_torch_main.pt')
train_targets_torch = torch.load('../data/databases/train_targets_torch_main.pt')

test_data_torch = torch.load('../data/databases/test_data_torch_main.pt')
test_targets_torch = torch.load('../data/databases/test_targets_torch_main.pt')

# %%
torch.sum(train_targets_torch==0)
# Out:
# tensor(7402)

# %%
torch.sum(train_targets_torch==1)
# Out:
# tensor(3967)

# %%
torch.sum(train_targets_torch==2)
# Out:
# tensor(4767)

# %%
print('Dim Train Data: ', train_data_torch.shape)
print('Dim Train Targets: ', train_targets_torch.shape)
print('Dim Test Data: ', test_data_torch.shape)
print('Dim Train Targets: ', test_targets_torch.shape)
# Out:
# Dim Train Data:  torch.Size([16136, 1, 35000])
# Dim Train Targets:  torch.Size([16136])
# Dim Test Data:  torch.Size([4042, 1, 35000])
# Dim Train Targets:  torch.Size([4042])

# %%
numChannels = 1
numClasses = 3

# %%
import matplotlib.pyplot as plt
i = 100

# %%
plt.plot(train_data_torch.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %% [markdown]
# # This is the formula for computing the size of the output of every layer
#
# $$L_{out} = \frac{L_{in}- Kernel_{size}}{stride}+1$$

# %% [markdown]
# # Here there's and example:
# $input size = 1 * 20'000 * 4 $
#
# after the first convolution:
# $output = \frac{20000-5000}{5}+1 = 3001$
# and the channels go from the initial 4 to the specified 32
#
# after the second convolution:
# $output = \frac{3001-2002}{1}+1 = 1000$
# and the channels go from 32 to 64
#
# after the last convolution:
# $output = \frac{1000-1000}{1}+1 = 1$
# and the channels go from 64 to 5 (as the number of classes!!!)

# %%
(35000-5000)/2+1
# Out:
# 15001.0

# %%
(15001-5000)/2+1
# Out:
# 5001.5

# %%
(5001-4500)/2+1
# Out:
# 251.5

# %%
KERNEL_SIZE = 64
POOL_FACT = 2
STRIDE_FACT = KERNEL_SIZE // 4
CHANNEL_COUNT = 32
use_avg_pool = True
model = torch.nn.Sequential() 
output_dim = 35000
model.append(torch.nn.Conv1d(in_channels = 1, out_channels = CHANNEL_COUNT, kernel_size = KERNEL_SIZE, stride=STRIDE_FACT)) #16x16896 - 512 + 1 
output_dim = (output_dim - KERNEL_SIZE) // STRIDE_FACT + 1
model.append(torch.nn.ReLU()) 
if use_avg_pool:
    model.append(torch.nn.AvgPool1d(POOL_FACT))
else:
    model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
output_dim /= POOL_FACT
model.append(torch.nn.Conv1d(in_channels = CHANNEL_COUNT, out_channels=CHANNEL_COUNT, kernel_size=KERNEL_SIZE // 2, stride=STRIDE_FACT // 2)) #16x7681
output_dim = (output_dim - KERNEL_SIZE // 2) // (STRIDE_FACT // 2)+ 1
model.append(torch.nn.ReLU())
if use_avg_pool:
    model.append(torch.nn.AvgPool1d(POOL_FACT))
else:
    model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
output_dim /= POOL_FACT
model.append(torch.nn.Flatten())
model.append(torch.nn.Linear(in_features = int(output_dim) * CHANNEL_COUNT, out_features = 9))
model.append(torch.nn.ReLU())
model.append(torch.nn.Linear(in_features = 9, out_features = 3))
# Out:
# Sequential(
#   (0): Conv1d(1, 32, kernel_size=(64,), stride=(16,))
#   (1): ReLU()
#   (2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (3): Conv1d(32, 32, kernel_size=(32,), stride=(8,))
#   (4): ReLU()
#   (5): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (6): Flatten(start_dim=1, end_dim=-1)
#   (7): Linear(in_features=2112, out_features=9, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=9, out_features=3, bias=True)
# )

# %%
#model, criterion = fastCNN(), nn.CrossEntropyLoss()

# %%
criterion = torch.nn.CrossEntropyLoss()

# %%
def count_parameters(model): return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
count_parameters(model)
# Out:
# 53927

# %%
def compute_nb_errors(model, testing_generator):
    nb_errors=0
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            predicted_classes = outputTest.max(1)[1]
            nb_errors += (predicted_classes != local_labels).long().sum()

    return nb_errors

# %%
if (torch.cuda.is_available()):
    model = model.cuda()

# %%
train_input = train_data_torch.view(train_data_torch.size(0), numChannels, -1).float()
train_target = train_targets_torch.long().view(-1)
test_input = test_data_torch.view(test_data_torch.size(0), numChannels, -1).float()
test_target = test_targets_torch.long().view(-1)

# %%
train_input.shape
# Out:
# torch.Size([16136, 1, 35000])

# %%
train_input = (train_input-torch.mean(train_input,2,keepdim=True))/torch.max(train_input,2,keepdim=True)[0]
test_input = (test_input-torch.mean(test_input,2,keepdim=True))/torch.max(test_input,2,keepdim=True)[0]

# %%
plt.plot(train_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
plt.plot(test_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
train_input.narrow(0, 0, 2).shape
# Out:
# torch.Size([2, 1, 35000])

# %%
out = model(train_input.narrow(0, 0, 2).cuda())
out.shape
# Out:
# torch.Size([2, 3])

# %%
lr = 3e-3

# %%
optimizer = optim.Adam(model.parameters(), lr = lr)
nb_epochs = 150
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', verbose=True, factor=0.2, patience = 30)

# %%
class errorsTable():
    def __init__(self):
        self.accuracyMatr = np.zeros((numClasses,numClasses))
    def newEntry(self,predictions,groundTruths):
        for pred,tru in zip(predictions,groundTruths):
            #print(pred, tru)
            self.accuracyMatr[pred,tru]+=1
    def getStats(self):
        #print(self.accuracyMatr)
        numEntry = np.sum(self.accuracyMatr,0)
        resultMatr = self.accuracyMatr/numEntry
        return resultMatr

# %%
np.set_printoptions(precision=2, suppress=True)

# %%
batch_size_train = 5000
batch_size_test = 1000

# %%
#torch.backends.cudnn.enabled = False

# %%
training_set = torch.utils.data.TensorDataset(train_input, train_target)
testing_set = torch.utils.data.TensorDataset(test_input, test_target)

# %%
# Generators
training_generator = torch.utils.data.DataLoader(training_set, batch_size=batch_size_train, num_workers=0,
                                                shuffle=True, drop_last=True)
testing_generator = torch.utils.data.DataLoader(testing_set, batch_size=batch_size_test, num_workers=0,
                                                 shuffle=False, drop_last=False)

# %%
loss_train = []
loss_test = []

t = time.time()
for k in range (nb_epochs):
    
    # Create a new error table
    accuracyTRAIN = errorsTable()
    accuracyTEST = errorsTable()
    print('Epoch: ', k)
    model.train()

    lossValue = 0
    for local_batch, local_labels in training_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()       
        model.zero_grad()
        output = model(local_batch)
        accuracyTRAIN.newEntry(output.max(1)[1], local_labels)
        loss = criterion(output, local_labels)
        lossValue += loss.item()*local_batch.size(0)
        loss.backward()
        optimizer.step()
    scheduler.step(lossValue/train_input.size(0))
    print('Loss is ', lossValue/train_input.size(0))
    loss_train.append(lossValue/train_input.size(0))    
    ################################################################    
    model.eval()
    lossValue = 0 
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
            lossTest = criterion(outputTest, local_labels)
            lossValue += lossTest.item()*local_batch.size(0)
    print('Loss TEST is ', lossValue/test_input.size(0))
    loss_test.append(lossValue/test_input.size(0))
    print("")
    print("The accuracy in TEST is: ")
    print("  1      2      3   ")
    print(accuracyTEST.getStats())
    print("The accuracy in TRAIN is: ")
    print("  1      2      3   ")
    print(accuracyTRAIN.getStats())
    print("----------------------")
    if k%10 == 0:
        #nb_test_errors = compute_nb_errors(model, test_input, test_target, batch_size_test)

        #print(k, ': Test accuracy Net {:0.2f}%% {:d}/{:d}'.format(100-(100 * nb_test_errors) / test_input.size(0),
                                                     #nb_test_errors, test_input.size(0)))
        

        #nb_train_errors = compute_nb_errors(model, train_input, train_target, batch_size_train)

        #print(k, ': Train accuracy Net {:0.2f}%% {:d}/{:d}'.format(100-(100 * nb_train_errors) / train_input.size(0),
                                                          #nb_train_errors, train_input.size(0)))
        print("Hey! Ten epochs are passed! We are getting older")
        
        


nb_test_errors = compute_nb_errors(model, testing_generator)  
print('Final Test error Net {:0.2f}% {:d}/{:d}'.format((100 * nb_test_errors) / test_input.size(0),
                                                  nb_test_errors, test_input.size(0)))

elapsed = time.time() - t
print(elapsed)
# Out:
# Epoch:  0
# Loss is  1.0047448511813972
# Loss TEST is  1.061099784141835
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  1
# Loss is  0.990199633441352
# Loss TEST is  1.0653535754063648
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# ----------------------
# Epoch:  2
# Loss is  0.9860445218447949
# Loss TEST is  1.056543870647021
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# ----------------------
# Epoch:  3
# Loss is  0.9786542994466582
# Loss TEST is  1.0450410897161984
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# ----------------------
# Epoch:  4
# Loss is  0.965918239296576
# Loss TEST is  1.0258051726205817
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# ----------------------
# Epoch:  5
# Loss is  0.9436227924231556
# Loss TEST is  0.9921647234755775
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 1. 1.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# ----------------------
# Epoch:  6
# Loss is  0.9055336107106037
# Loss TEST is  0.9361200952577096
#
# The accuracy in TEST is:
#   1      2      3
# [[0.97 1.   0.91]
#  [0.   0.   0.  ]
#  [0.03 0.   0.09]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   1.   0.99]
#  [0.   0.   0.  ]
#  [0.   0.   0.01]]
# ----------------------
# Epoch:  7
# Loss is  0.8454261902658787
# Loss TEST is  0.858369780377195
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.93 0.23]
#  [0.   0.   0.  ]
#  [0.13 0.07 0.77]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.91 0.98 0.63]
#  [0.   0.   0.  ]
#  [0.09 0.02 0.37]]
# ----------------------
# Epoch:  8
# Loss is  0.7737933643749579
# Loss TEST is  0.7958402020219881
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.89 0.2 ]
#  [0.   0.   0.  ]
#  [0.13 0.11 0.8 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.87 0.94 0.23]
#  [0.   0.   0.  ]
#  [0.13 0.06 0.77]]
# ----------------------
# Epoch:  9
# Loss is  0.7223619363304407
# Loss TEST is  0.7507319644440053
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.92 0.2 ]
#  [0.   0.   0.  ]
#  [0.13 0.08 0.8 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.87 0.93 0.21]
#  [0.   0.   0.  ]
#  [0.13 0.07 0.79]]
# ----------------------
# Epoch:  10
# Loss is  0.68307565649843
# Loss TEST is  0.7231053077366493
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.93 0.18]
#  [0.   0.   0.  ]
#  [0.13 0.07 0.82]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.87 0.93 0.21]
#  [0.   0.   0.  ]
#  [0.13 0.07 0.79]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  11
# Loss is  0.656219434785441
# Loss TEST is  0.6799918599555776
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.93 0.2 ]
#  [0.   0.   0.  ]
#  [0.13 0.07 0.8 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.87 0.94 0.2 ]
#  [0.   0.   0.  ]
#  [0.13 0.06 0.8 ]]
# ----------------------
# Epoch:  12
# Loss is  0.6213333562984287
# Loss TEST is  0.6394349156718984
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.93 0.2 ]
#  [0.   0.   0.  ]
#  [0.13 0.07 0.8 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.87 0.94 0.16]
#  [0.   0.   0.  ]
#  [0.13 0.06 0.84]]
# ----------------------
# Epoch:  13
# Loss is  0.5852229557063359
# Loss TEST is  0.6016367863806564
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.94 0.05]
#  [0.   0.   0.  ]
#  [0.13 0.06 0.95]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.87 0.94 0.1 ]
#  [0.   0.   0.  ]
#  [0.13 0.06 0.9 ]]
# ----------------------
# Epoch:  14
# Loss is  0.5511181169532583
# Loss TEST is  0.5703270697817833
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.83 0.03]
#  [0.07 0.13 0.01]
#  [0.13 0.04 0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.87 0.96 0.06]
#  [0.   0.   0.  ]
#  [0.13 0.04 0.94]]
# ----------------------
# Epoch:  15
# Loss is  0.5218296888504633
# Loss TEST is  0.5454054517300043
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.63 0.04]
#  [0.   0.34 0.01]
#  [0.13 0.03 0.95]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.81 0.59 0.05]
#  [0.06 0.4  0.02]
#  [0.13 0.01 0.94]]
# ----------------------
# Epoch:  16
# Loss is  0.4929686994852852
# Loss TEST is  0.5076823480821729
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.26 0.02]
#  [0.08 0.74 0.06]
#  [0.12 0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.84 0.5  0.05]
#  [0.03 0.48 0.03]
#  [0.12 0.02 0.92]]
# ----------------------
# Epoch:  17
# Loss is  0.46342696272387146
# Loss TEST is  0.47374211444175224
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.33 0.05]
#  [0.07 0.67 0.03]
#  [0.12 0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.82 0.39 0.06]
#  [0.06 0.61 0.03]
#  [0.12 0.01 0.91]]
# ----------------------
# Epoch:  18
# Loss is  0.4351081443884967
# Loss TEST is  0.45322825302881864
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.38 0.06]
#  [0.07 0.62 0.02]
#  [0.12 0.01 0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.81 0.28 0.04]
#  [0.08 0.72 0.05]
#  [0.12 0.   0.91]]
# ----------------------
# Epoch:  19
# Loss is  0.4168066907679615
# Loss TEST is  0.4310358495242757
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8  0.26 0.02]
#  [0.07 0.74 0.06]
#  [0.12 0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.81 0.31 0.06]
#  [0.07 0.68 0.03]
#  [0.12 0.   0.91]]
# ----------------------
# Epoch:  20
# Loss is  0.40209504471418583
# Loss TEST is  0.40987793885204593
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.26 0.03]
#  [0.07 0.74 0.05]
#  [0.12 0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.8  0.28 0.05]
#  [0.07 0.71 0.04]
#  [0.12 0.01 0.91]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  21
# Loss is  0.3850694152909337
# Loss TEST is  0.3958751402946465
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.3  0.05]
#  [0.07 0.7  0.03]
#  [0.12 0.01 0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.81 0.24 0.04]
#  [0.08 0.75 0.05]
#  [0.12 0.01 0.91]]
# ----------------------
# Epoch:  22
# Loss is  0.3692897264769483
# Loss TEST is  0.38567297549191115
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.31 0.06]
#  [0.07 0.68 0.02]
#  [0.12 0.01 0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.82 0.21 0.04]
#  [0.08 0.79 0.05]
#  [0.1  0.   0.91]]
# ----------------------
# Epoch:  23
# Loss is  0.3525936199434334
# Loss TEST is  0.36385593630782687
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8  0.15 0.02]
#  [0.07 0.84 0.06]
#  [0.12 0.01 0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.82 0.25 0.05]
#  [0.08 0.75 0.04]
#  [0.1  0.   0.91]]
# ----------------------
# Epoch:  24
# Loss is  0.335947205494936
# Loss TEST is  0.348969949782632
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.09 0.02]
#  [0.07 0.91 0.06]
#  [0.08 0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.82 0.22 0.05]
#  [0.07 0.77 0.04]
#  [0.1  0.01 0.91]]
# ----------------------
# Epoch:  25
# Loss is  0.318934467755513
# Loss TEST is  0.32813083936028525
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.11 0.04]
#  [0.07 0.89 0.04]
#  [0.04 0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.82 0.21 0.05]
#  [0.07 0.78 0.04]
#  [0.1  0.   0.91]]
# ----------------------
# Epoch:  26
# Loss is  0.30449012097711897
# Loss TEST is  0.30692342624901425
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.17 0.05]
#  [0.07 0.82 0.03]
#  [0.08 0.01 0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.85 0.15 0.05]
#  [0.07 0.84 0.04]
#  [0.08 0.01 0.91]]
# ----------------------
# Epoch:  27
# Loss is  0.28634048632660536
# Loss TEST is  0.29484680725583223
#
# The accuracy in TEST is:
#   1      2      3
# [[0.86 0.19 0.06]
#  [0.06 0.78 0.02]
#  [0.08 0.03 0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.87 0.1  0.06]
#  [0.07 0.88 0.03]
#  [0.06 0.02 0.91]]
# ----------------------
# Epoch:  28
# Loss is  0.2717776302512353
# Loss TEST is  0.28207698831577105
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.02 0.04]
#  [0.07 0.93 0.03]
#  [0.12 0.05 0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.88 0.07 0.06]
#  [0.07 0.92 0.04]
#  [0.04 0.01 0.91]]
# ----------------------
# Epoch:  29
# Loss is  0.25338671056126155
# Loss TEST is  0.2542132791915133
#
# The accuracy in TEST is:
#   1      2      3
# [[0.86 0.   0.04]
#  [0.07 0.98 0.03]
#  [0.07 0.02 0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.89 0.03 0.07]
#  [0.06 0.95 0.02]
#  [0.05 0.02 0.91]]
# ----------------------
# Epoch:  30
# Loss is  0.23521518036464564
# Loss TEST is  0.2356097152745116
#
# The accuracy in TEST is:
#   1      2      3
# [[0.91 0.   0.05]
#  [0.07 1.   0.03]
#  [0.02 0.   0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.88 0.   0.05]
#  [0.07 0.99 0.03]
#  [0.05 0.01 0.92]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  31
# Loss is  0.22297020471503845
# Loss TEST is  0.2300306687934277
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.02 0.08]
#  [0.   0.98 0.02]
#  [0.   0.   0.9 ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.93 0.04 0.05]
#  [0.05 0.95 0.03]
#  [0.02 0.01 0.93]]
# ----------------------
# Epoch:  32
# Loss is  0.21904293700764543
# Loss TEST is  0.20674395842135748
#
# The accuracy in TEST is:
#   1      2      3
# [[0.93 0.   0.04]
#  [0.06 1.   0.03]
#  [0.   0.   0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.93 0.03 0.06]
#  [0.02 0.96 0.02]
#  [0.04 0.   0.92]]
# ----------------------
# Epoch:  33
# Loss is  0.20001144099927032
# Loss TEST is  0.228427373193562
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.   0.  ]
#  [0.07 1.   0.04]
#  [0.08 0.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.07 0.05]
#  [0.04 0.93 0.03]
#  [0.02 0.   0.92]]
# ----------------------
# Epoch:  34
# Loss is  0.19527406117291987
# Loss TEST is  0.21170427742009112
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.   0.  ]
#  [0.07 1.   0.03]
#  [0.12 0.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.95 0.03 0.06]
#  [0.02 0.97 0.02]
#  [0.03 0.   0.92]]
# ----------------------
# Epoch:  35
# Loss is  0.18148923576262307
# Loss TEST is  0.16497500021082526
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.03]
#  [0.   1.   0.02]
#  [0.01 0.   0.95]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.93 0.01 0.04]
#  [0.03 0.99 0.02]
#  [0.04 0.   0.94]]
# ----------------------
# Epoch:  36
# Loss is  0.16397289584548272
# Loss TEST is  0.1668924059919766
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.06]
#  [0.   1.   0.02]
#  [0.   0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.   0.03]
#  [0.02 1.   0.02]
#  [0.04 0.   0.95]]
# ----------------------
# Epoch:  37
# Loss is  0.15248287326933785
# Loss TEST is  0.16355100862833016
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.02 0.06]
#  [0.   0.98 0.01]
#  [0.   0.   0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.97 0.   0.03]
#  [0.02 1.   0.02]
#  [0.01 0.   0.95]]
# ----------------------
# Epoch:  38
# Loss is  0.14151633062839036
# Loss TEST is  0.14139834329493267
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.03]
#  [0.   1.   0.02]
#  [0.01 0.   0.95]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.04]
#  [0.   0.99 0.02]
#  [0.   0.   0.94]]
# ----------------------
# Epoch:  39
# Loss is  0.13165827425003762
# Loss TEST is  0.13928096656646544
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.01]
#  [0.   1.   0.03]
#  [0.01 0.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.03]
#  [0.   0.99 0.02]
#  [0.01 0.   0.95]]
# ----------------------
# Epoch:  40
# Loss is  0.1230595950138823
# Loss TEST is  0.1276955199858772
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.01]
#  [0.   1.   0.03]
#  [0.01 0.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.03]
#  [0.   0.99 0.02]
#  [0.01 0.   0.95]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  41
# Loss is  0.1149441322877848
# Loss TEST is  0.11703041763418622
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.03]
#  [0.   1.   0.02]
#  [0.01 0.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.03]
#  [0.   0.99 0.02]
#  [0.01 0.   0.95]]
# ----------------------
# Epoch:  42
# Loss is  0.10729671340947347
# Loss TEST is  0.11062034015266804
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01 0.04]
#  [0.   0.99 0.02]
#  [0.   0.   0.95]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.   0.03]
#  [0.   1.   0.02]
#  [0.01 0.   0.95]]
# ----------------------
# Epoch:  43
# Loss is  0.10009608002925309
# Loss TEST is  0.10553784745495134
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.03]
#  [0.   1.   0.02]
#  [0.01 0.   0.95]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.   0.03]
#  [0.   1.   0.02]
#  [0.01 0.   0.96]]
# ----------------------
# Epoch:  44
# Loss is  0.09141193336198161
# Loss TEST is  0.10206272669472002
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.03]
#  [0.   1.   0.01]
#  [0.01 0.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.   0.02]
#  [0.   1.   0.02]
#  [0.01 0.   0.96]]
# ----------------------
# Epoch:  45
# Loss is  0.08536430918895554
# Loss TEST is  0.09340384759226393
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.01]
#  [0.   1.   0.02]
#  [0.01 0.   0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.   0.01]
#  [0.   1.   0.02]
#  [0.01 0.   0.97]]
# ----------------------
# Epoch:  46
# Loss is  0.081108435138831
# Loss TEST is  0.08790642997634288
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.02]
#  [0.   1.   0.02]
#  [0.01 0.   0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.   0.01]
#  [0.   1.   0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Epoch:  47
# Loss is  0.07715532634671395
# Loss TEST is  0.08378885428705526
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.01 0.01]
#  [0.   0.99 0.02]
#  [0.01 0.   0.97]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.01]
#  [0.   0.99 0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Epoch:  48
# Loss is  0.07376914227960366
# Loss TEST is  0.08017012776455804
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.01 0.01]
#  [0.   0.99 0.02]
#  [0.01 0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Epoch:  49
# Loss is  0.07032253075322717
# Loss TEST is  0.07745844280584091
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.01]
#  [0.   1.   0.02]
#  [0.01 0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Epoch:  50
# Loss is  0.06702380651034633
# Loss TEST is  0.07456550505869404
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.01 0.01]
#  [0.   0.99 0.01]
#  [0.01 0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.   0.  ]
#  [0.   1.   0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  51
# Loss is  0.06558362488765555
# Loss TEST is  0.07101004581045008
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.01 0.01]
#  [0.   0.99 0.02]
#  [0.01 0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Epoch:  52
# Loss is  0.06191935768857946
# Loss TEST is  0.06891555244537169
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.01]
#  [0.   1.   0.02]
#  [0.01 0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Epoch:  53
# Loss is  0.06112524474027669
# Loss TEST is  0.06676975449658691
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.01 0.01]
#  [0.   0.99 0.02]
#  [0.01 0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Epoch:  54
# Loss is  0.05883731254564398
# Loss TEST is  0.06418473125868124
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01 0.01]
#  [0.   0.99 0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Epoch:  55
# Loss is  0.056507784815991814
# Loss TEST is  0.06341242310966612
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.   0.01]
#  [0.   1.   0.02]
#  [0.01 0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  56
# Loss is  0.05516996902695787
# Loss TEST is  0.06062688884214267
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.01 0.   0.98]]
# ----------------------
# Epoch:  57
# Loss is  0.05291014966076119
# Loss TEST is  0.05904881624096635
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01 0.01]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  58
# Loss is  0.0519317241887025
# Loss TEST is  0.057256261328256466
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  59
# Loss is  0.04994132693156962
# Loss TEST is  0.055442261583789745
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01 0.01]
#  [0.   0.99 0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  60
# Loss is  0.04924211815465011
# Loss TEST is  0.0542048891819184
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01 0.01]
#  [0.   0.99 0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  61
# Loss is  0.047361421415902744
# Loss TEST is  0.052756922290960434
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  62
# Loss is  0.04700113186704149
# Loss TEST is  0.05160439599126592
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01 0.01]
#  [0.   0.99 0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  63
# Loss is  0.04534623814200965
# Loss TEST is  0.050529270835187635
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01 0.01]
#  [0.   0.99 0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  64
# Loss is  0.04380227315452469
# Loss TEST is  0.04913205191408243
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  65
# Loss is  0.04315747194690284
# Loss TEST is  0.04848158557865656
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  66
# Loss is  0.041287276251116896
# Loss TEST is  0.046937142472524326
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  67
# Loss is  0.03854287017171904
# Loss TEST is  0.047126472515193675
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01 0.01]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  68
# Loss is  0.03960032069600332
# Loss TEST is  0.045140293394093284
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  69
# Loss is  0.03857465726856731
# Loss TEST is  0.04440957022566332
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01 0.01]
#  [0.   0.99 0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  70
# Loss is  0.03869323005431586
# Loss TEST is  0.04394879424552821
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.01]
#  [0.   0.   0.98]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  71
# Loss is  0.03699993601103023
# Loss TEST is  0.04308116648259551
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  72
# Loss is  0.03793109697786132
# Loss TEST is  0.041702276504036816
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  73
# Loss is  0.035186591625110196
# Loss TEST is  0.041384201544765076
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  74
# Loss is  0.03600983437654933
# Loss TEST is  0.04001108457632492
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  75
# Loss is  0.03479485493291855
# Loss TEST is  0.03983060594229696
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  76
# Loss is  0.03397788429502573
# Loss TEST is  0.03811398017202227
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  77
# Loss is  0.03306430163777105
# Loss TEST is  0.03757965448969133
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  78
# Loss is  0.032372881201717836
# Loss TEST is  0.03646879467259741
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  79
# Loss is  0.03134044179075061
# Loss TEST is  0.03585406451060712
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  80
# Loss is  0.030807257885271274
# Loss TEST is  0.03508358593534296
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  81
# Loss is  0.02994045202403773
# Loss TEST is  0.033818029748798446
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  82
# Loss is  0.02918048737774731
# Loss TEST is  0.03345292376078765
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  83
# Loss is  0.029071951589750723
# Loss TEST is  0.0333616751854901
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  84
# Loss is  0.028662363009090523
# Loss TEST is  0.03154663890342144
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  85
# Loss is  0.027160093407148943
# Loss TEST is  0.03072105945244188
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  86
# Loss is  0.025971015073990668
# Loss TEST is  0.030456315214528653
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  87
# Loss is  0.026210530508211715
# Loss TEST is  0.029512198177387018
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  88
# Loss is  0.024957506283452797
# Loss TEST is  0.0286581926821984
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  89
# Loss is  0.024342732956511997
# Loss TEST is  0.028188873303133417
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  90
# Loss is  0.023543280602447102
# Loss TEST is  0.02758242217210969
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  91
# Loss is  0.02332429166552627
# Loss TEST is  0.028304797921187803
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  92
# Loss is  0.02268792465273762
# Loss TEST is  0.02721870018013526
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  93
# Loss is  0.02335847113475418
# Loss TEST is  0.026299643170370552
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  94
# Loss is  0.022962290805662453
# Loss TEST is  0.02633887842594324
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  95
# Loss is  0.02212401160422711
# Loss TEST is  0.024718651222226377
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  96
# Loss is  0.02147377922070842
# Loss TEST is  0.025262289275477454
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  97
# Loss is  0.02056207005941135
# Loss TEST is  0.024279251268879132
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  98
# Loss is  0.021250030357366632
# Loss TEST is  0.02327783742503902
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  99
# Loss is  0.020008713462245482
# Loss TEST is  0.02369347327162559
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.02]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  100
# Loss is  0.019307014193934383
# Loss TEST is  0.02298565160617682
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  101
# Loss is  0.01919661356754006
# Loss TEST is  0.02181677593177259
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  102
# Loss is  0.01845601011099027
# Loss TEST is  0.0211190693969813
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  103
# Loss is  0.01826395484285007
# Loss TEST is  0.020622053534301243
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  104
# Loss is  0.01755141342371835
# Loss TEST is  0.020494191975548002
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  105
# Loss is  0.017465117175536518
# Loss TEST is  0.02002537884011695
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  106
# Loss is  0.016700255236208408
# Loss TEST is  0.019327663846695514
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  107
# Loss is  0.015696371343572303
# Loss TEST is  0.018937152132294237
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  108
# Loss is  0.015636345595084446
# Loss TEST is  0.019121081851245832
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  109
# Loss is  0.01562915549160572
# Loss TEST is  0.01816156670522131
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  110
# Loss is  0.015084268008097895
# Loss TEST is  0.017600173763110533
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  111
# Loss is  0.014887481672069668
# Loss TEST is  0.017324029871680576
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  112
# Loss is  0.014150345856836366
# Loss TEST is  0.016778070810502085
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  113
# Loss is  0.01433458305982135
# Loss TEST is  0.016751409189859456
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  114
# Loss is  0.013244396281540838
# Loss TEST is  0.015889595117316732
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  115
# Loss is  0.01359582077767229
# Loss TEST is  0.015255018990838929
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  116
# Loss is  0.012752863030878843
# Loss TEST is  0.014916647846346472
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  117
# Loss is  0.012303090097459312
# Loss TEST is  0.014163079085740925
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  118
# Loss is  0.012535952485499402
# Loss TEST is  0.014032532566055132
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  119
# Loss is  0.011816214325426384
# Loss TEST is  0.013449341956413601
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Epoch:  120
# Loss is  0.011379629741554428
# Loss TEST is  0.013020540371939046
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  121
# Loss is  0.010932027258396326
# Loss TEST is  0.012578878358636882
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.01]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  122
# Loss is  0.010382835236117133
# Loss TEST is  0.012018626923536913
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  123
# Loss is  0.010683130492291417
# Loss TEST is  0.012091378531594314
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  124
# Loss is  0.0098451996133485
# Loss TEST is  0.011140558341004688
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  125
# Loss is  0.0096352367597712
# Loss TEST is  0.01078901685892297
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  126
# Loss is  0.009754458285339941
# Loss TEST is  0.010664988449004648
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  127
# Loss is  0.008982435245358699
# Loss TEST is  0.010288327341122328
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  128
# Loss is  0.0091551389913668
# Loss TEST is  0.009892651755712974
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  129
# Loss is  0.009105362062262585
# Loss TEST is  0.00963740667085385
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  130
# Loss is  0.008591423912392168
# Loss TEST is  0.009365074761407261
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  131
# Loss is  0.008803515082772823
# Loss TEST is  0.008431415582552206
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  132
# Loss is  0.007342478696969797
# Loss TEST is  0.007417768842039767
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.01]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  133
# Loss is  0.00670776383519121
# Loss TEST is  0.0067988929090139405
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.   0.  ]
#  [0.   1.   0.  ]
#  [0.   0.   0.99]]
# ----------------------
# Epoch:  134
# Loss is  0.006167773933306403
# Loss TEST is  0.0061945558589215416
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  135
# Loss is  0.005733824277783333
# Loss TEST is  0.0060806168479575805
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  136
# Loss is  0.005613388673734358
# Loss TEST is  0.00470412243030899
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  137
# Loss is  0.005082632636630157
# Loss TEST is  0.006156070942666523
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  138
# Loss is  0.0049001986590751076
# Loss TEST is  0.003911911867183846
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  139
# Loss is  0.004069423902688394
# Loss TEST is  0.003740581391883377
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  140
# Loss is  0.003641731065689195
# Loss TEST is  0.003905035978628305
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  141
# Loss is  0.0034717481743117696
# Loss TEST is  0.0032357161532039582
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  142
# Loss is  0.0030853274403242455
# Loss TEST is  0.00313919443334833
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  143
# Loss is  0.0028962263480534368
# Loss TEST is  0.0028879636917530545
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  144
# Loss is  0.002667526226217388
# Loss TEST is  0.00284723202556921
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  145
# Loss is  0.0026133457735738634
# Loss TEST is  0.0025662707781464317
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  146
# Loss is  0.002414952450139604
# Loss TEST is  0.0025223417890537854
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  147
# Loss is  0.0023822829315007605
# Loss TEST is  0.002367086223299435
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  148
# Loss is  0.002233978642204321
# Loss TEST is  0.002356212721876745
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  149
# Loss is  0.0021810017346765107
# Loss TEST is  0.0021886142671319305
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Final Test error Net 0.00% 0/4042
# 789.3822159767151

# %%
accuracyTEST = errorsTable()

model.eval()
lossValue = 0 
with torch.set_grad_enabled(False):
    for local_batch, local_labels in testing_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
        outputTest = model(local_batch)
        accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
        lossTest = criterion(outputTest, local_labels)
        lossValue += lossTest.item()*local_batch.size(0)
print('Loss TEST is ', lossValue/test_input.size(0))

print("")
print("The accuracy in TEST is: ")
print("  1      2      3   ")
print(accuracyTEST.getStats())
# Out:
# Loss TEST is  0.0021886142671319305
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
plt.figure()
plt.plot(np.array(loss_test)/max(loss_test))
plt.plot(np.array(loss_train)/max(loss_train))

# %%
torch.save(model, '../Models/model_main_another')
