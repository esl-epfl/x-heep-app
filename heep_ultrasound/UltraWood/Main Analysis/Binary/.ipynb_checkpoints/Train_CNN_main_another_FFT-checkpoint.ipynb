# %%
import torch
import torch.utils.data
import glob
import random
import numpy as np
import pandas as pd
from torch import nn, optim
from torch.nn import functional as F
import time
from torch.nn.utils import weight_norm

# %%
seed = 1995
random.seed(seed)     # python random generator
np.random.seed(seed)  # numpy random generator

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
Fs = 100000

# %%
train_data_torch = torch.load('../../data/databases/train_data_torch_main.pt')
train_targets_torch = torch.load('../../data/databases/train_targets_torch_main.pt')

test_data_torch = torch.load('../../data/databases/valid_data_torch_main.pt')
test_targets_torch = torch.load('../../data/databases/valid_targets_torch_main.pt')

# %%
train_targets_torch[torch.where(train_targets_torch==2)] = 1
test_targets_torch[torch.where(test_targets_torch==2)] = 1

# %%
print('Dim Train Data: ', train_data_torch.shape)
print('Dim Train Targets: ', train_targets_torch.shape)
print('Dim Test Data: ', test_data_torch.shape)
print('Dim Train Targets: ', test_targets_torch.shape)
# Out:
# Dim Train Data:  torch.Size([6624, 1, 35000])
# Dim Train Targets:  torch.Size([6624])
# Dim Test Data:  torch.Size([1658, 1, 35000])
# Dim Train Targets:  torch.Size([1658])

# %%
numChannels = 1
numClasses = 2

# %%
import matplotlib.pyplot as plt
i = 100

# %%
plt.plot(train_data_torch.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %% [markdown]
# # This is the formula for computing the size of the output of every layer
#
# $$L_{out} = \frac{L_{in}- Kernel_{size}}{stride}+1$$

# %% [markdown]
# # Here there's and example:
# $input size = 1 * 20'000 * 4 $
#
# after the first convolution:
# $output = \frac{20000-5000}{5}+1 = 3001$
# and the channels go from the initial 4 to the specified 32
#
# after the second convolution:
# $output = \frac{3001-2002}{1}+1 = 1000$
# and the channels go from 32 to 64
#
# after the last convolution:
# $output = \frac{1000-1000}{1}+1 = 1$
# and the channels go from 64 to 5 (as the number of classes!!!)

# %%
(35000-5000)/2+1
# Out:
# 15001.0

# %%
(15001-5000)/2+1
# Out:
# 5001.5

# %%
(5001-4500)/2+1
# Out:
# 251.5

# %%
KERNEL_SIZE = 128
POOL_FACT = 2
STRIDE_FACT = KERNEL_SIZE // 4
CHANNEL_COUNT = 1
use_avg_pool = True
model = torch.nn.Sequential() 
output_dim = 35000//2
model.append(torch.nn.Conv1d(in_channels = 1, out_channels = CHANNEL_COUNT, kernel_size = KERNEL_SIZE, stride=STRIDE_FACT)) #16x16896 - 512 + 1 
output_dim = (output_dim - KERNEL_SIZE) // STRIDE_FACT + 1
model.append(torch.nn.ReLU()) 
if use_avg_pool:
    model.append(torch.nn.AvgPool1d(POOL_FACT))
else:
    model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
output_dim /= POOL_FACT
model.append(torch.nn.Conv1d(in_channels = CHANNEL_COUNT, out_channels=CHANNEL_COUNT, kernel_size=KERNEL_SIZE // 2, stride=STRIDE_FACT // 2)) #16x7681
output_dim = (output_dim - KERNEL_SIZE // 2) // (STRIDE_FACT // 2)+ 1
model.append(torch.nn.ReLU())
if use_avg_pool:
    model.append(torch.nn.AvgPool1d(POOL_FACT))
else:
    model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
output_dim /= POOL_FACT
model.append(torch.nn.Flatten())
model.append(torch.nn.Linear(in_features = int(output_dim) * CHANNEL_COUNT, out_features = 9))
model.append(torch.nn.ReLU())
model.append(torch.nn.Linear(in_features = 9, out_features = 2))
# Out:
# Sequential(
#   (0): Conv1d(1, 1, kernel_size=(128,), stride=(32,))
#   (1): ReLU()
#   (2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (3): Conv1d(1, 1, kernel_size=(64,), stride=(16,))
#   (4): ReLU()
#   (5): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (6): Flatten(start_dim=1, end_dim=-1)
#   (7): Linear(in_features=6, out_features=9, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=9, out_features=2, bias=True)
# )

# %%
#model, criterion = fastCNN(), nn.CrossEntropyLoss()

# %%
criterion = torch.nn.CrossEntropyLoss()

# %%
def count_parameters(model): return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
count_parameters(model)
# Out:
# 277

# %%
def compute_nb_errors(model, testing_generator):
    nb_errors=0
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            predicted_classes = outputTest.max(1)[1]
            nb_errors += (predicted_classes != local_labels).long().sum()

    return nb_errors

# %%
if (torch.cuda.is_available()):
    model = model.cuda()

# %%
train_input = train_data_torch.view(train_data_torch.size(0), numChannels, -1).float()
train_target = train_targets_torch.long().view(-1)
test_input = test_data_torch.view(test_data_torch.size(0), numChannels, -1).float()
test_target = test_targets_torch.long().view(-1)

# %%
train_input.shape
# Out:
# torch.Size([6624, 1, 35000])

# %%
train_input = np.abs(torch.fft.fft(train_input)).narrow(2,1,train_input.shape[-1]//2)
test_input = np.abs(torch.fft.fft(test_input)).narrow(2,1,test_input.shape[-1]//2)

# %%
train_input = train_input/torch.max(train_input,2,keepdim=True)[0]
test_input = test_input/torch.max(test_input,2,keepdim=True)[0]

# %%
train_input.shape
# Out:
# torch.Size([6624, 1, 17500])

# %%
plt.plot(train_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
plt.plot(test_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
train_input.narrow(0, 0, 2).shape
# Out:
# torch.Size([2, 1, 17500])

# %%
out = model(train_input.narrow(0, 0, 2).cuda())
out.shape
# Out:
# torch.Size([2, 2])

# %%
lr = 3e-4

# %%
optimizer = optim.Adam(model.parameters(), lr = lr)
nb_epochs = 150
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', verbose=True, factor=0.2, patience = 30)

# %%
class errorsTable():
    def __init__(self):
        self.accuracyMatr = np.zeros((numClasses,numClasses))
    def newEntry(self,predictions,groundTruths):
        for pred,tru in zip(predictions,groundTruths):
            #print(pred, tru)
            self.accuracyMatr[pred,tru]+=1
    def getStats(self):
        #print(self.accuracyMatr)
        numEntry = np.sum(self.accuracyMatr,0)
        resultMatr = self.accuracyMatr/numEntry
        return resultMatr

# %%
np.set_printoptions(precision=2, suppress=True)

# %%
batch_size_train = 32
batch_size_test = 1000

# %%
#torch.backends.cudnn.enabled = False

# %%
training_set = torch.utils.data.TensorDataset(train_input, train_target)
testing_set = torch.utils.data.TensorDataset(test_input, test_target)

# %%
# Generators
training_generator = torch.utils.data.DataLoader(training_set, batch_size=batch_size_train, num_workers=0,
                                                shuffle=True, drop_last=True)
testing_generator = torch.utils.data.DataLoader(testing_set, batch_size=batch_size_test, num_workers=0,
                                                 shuffle=False, drop_last=False)

# %%
loss_train = []
loss_test = []

t = time.time()

# initialize best validation loss and best model
best_val_loss = float("inf")
best_model = None

for k in range (nb_epochs):
    
    # Create a new error table
    accuracyTRAIN = errorsTable()
    accuracyTEST = errorsTable()
    print('Epoch: ', k)
    model.train()

    lossValue = 0
    for local_batch, local_labels in training_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()       
        model.zero_grad()
        output = model(local_batch)
        accuracyTRAIN.newEntry(output.max(1)[1], local_labels)
        loss = criterion(output, local_labels)
        lossValue += loss.item()*local_batch.size(0)
        loss.backward()
        optimizer.step()
    scheduler.step(lossValue/train_input.size(0))
    print('Loss is ', lossValue/train_input.size(0))
    loss_train.append(lossValue/train_input.size(0))    
    ################################################################    
    model.eval()
    lossValue = 0 
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
            lossTest = criterion(outputTest, local_labels)
            lossValue += lossTest.item()*local_batch.size(0)
    print('Loss TEST is ', lossValue/test_input.size(0))
    val_loss = lossValue/test_input.size(0)
    loss_test.append(val_loss)
    print("")
    print("The accuracy in TEST is: ")
    print("  1      2      3   ")
    print(accuracyTEST.getStats())
    print("The accuracy in TRAIN is: ")
    print("  1      2      3   ")
    print(accuracyTRAIN.getStats())
    print("----------------------")
    # check if validation loss has decreased
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        print('Best validation loss: ', best_val_loss)
        best_model = model
        torch.save(best_model, '../../Models/model_main_another_FFT_binary')
        
        


nb_test_errors = compute_nb_errors(model, testing_generator)  
print('Final Test error Net {:0.2f}% {:d}/{:d}'.format((100 * nb_test_errors) / test_input.size(0),
                                                  nb_test_errors, test_input.size(0)))

elapsed = time.time() - t
print(elapsed)
# Out:
# Epoch:  0
# Loss is  0.5958181606686633
# Loss TEST is  0.5903435542873939
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5903435542873939
# Epoch:  1
# Loss is  0.5947028905297247
# Loss TEST is  0.5896923324526866
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5896923324526866
# Epoch:  2
# Loss is  0.5937743751323166
# Loss TEST is  0.5903652212947643
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Epoch:  3
# Loss is  0.5933547734062453
# Loss TEST is  0.5872359175877634
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5872359175877634
# Epoch:  4
# Loss is  0.5924593038892977
# Loss TEST is  0.5858599826855309
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5858599826855309
# Epoch:  5
# Loss is  0.591707136751949
# Loss TEST is  0.5842207889505118
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5842207889505118
# Epoch:  6
# Loss is  0.5907381719725143
# Loss TEST is  0.5830215240128797
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5830215240128797
# Epoch:  7
# Loss is  0.5896255815950568
# Loss TEST is  0.5819707025377253
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5819707025377253
# Epoch:  8
# Loss is  0.5885001069681656
# Loss TEST is  0.5789061355504541
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5789061355504541
# Epoch:  9
# Loss is  0.586770315533099
# Loss TEST is  0.5795231502867147
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Epoch:  10
# Loss is  0.5853671129199042
# Loss TEST is  0.5741866136416883
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5741866136416883
# Epoch:  11
# Loss is  0.5842077041017837
# Loss TEST is  0.5715136596319615
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5715136596319615
# Epoch:  12
# Loss is  0.5825445785902549
# Loss TEST is  0.5678456019075414
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5678456019075414
# Epoch:  13
# Loss is  0.5801813981095374
# Loss TEST is  0.5674378627100094
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5674378627100094
# Epoch:  14
# Loss is  0.5782189372081111
# Loss TEST is  0.5616574185676828
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5616574185676828
# Epoch:  15
# Loss is  0.5761106774426888
# Loss TEST is  0.5579741820063896
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5579741820063896
# Epoch:  16
# Loss is  0.5736787516425773
# Loss TEST is  0.5608378859782823
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Epoch:  17
# Loss is  0.5716540693948811
# Loss TEST is  0.5522755779532673
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5522755779532673
# Epoch:  18
# Loss is  0.5689500574616418
# Loss TEST is  0.5450402683026828
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5450402683026828
# Epoch:  19
# Loss is  0.5649341282925168
# Loss TEST is  0.5399802652501082
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5399802652501082
# Epoch:  20
# Loss is  0.5617090646483472
# Loss TEST is  0.5354978740574798
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5354978740574798
# Epoch:  21
# Loss is  0.5583844822673982
# Loss TEST is  0.53298289827616
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.53298289827616
# Epoch:  22
# Loss is  0.551671225235658
# Loss TEST is  0.5202803635122693
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5202803635122693
# Epoch:  23
# Loss is  0.5418495089535552
# Loss TEST is  0.49537029215308814
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.49537029215308814
# Epoch:  24
# Loss is  0.5304832151834515
# Loss TEST is  0.47720134714831774
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.47720134714831774
# Epoch:  25
# Loss is  0.5159945215867914
# Loss TEST is  0.45457947635247997
#
# The accuracy in TEST is:
#   1      2      3
# [[0.78 0.  ]
#  [0.22 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.02 0.  ]
#  [0.98 1.  ]]
# ----------------------
# Best validation loss:  0.45457947635247997
# Epoch:  26
# Loss is  0.5008667988189752
# Loss TEST is  0.44658386319048876
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.16 0.  ]
#  [0.84 1.  ]]
# ----------------------
# Best validation loss:  0.44658386319048876
# Epoch:  27
# Loss is  0.48326709045880084
# Loss TEST is  0.4122886682160657
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.27 0.01]
#  [0.73 0.99]]
# ----------------------
# Best validation loss:  0.4122886682160657
# Epoch:  28
# Loss is  0.4643070226994114
# Loss TEST is  0.38709052559550045
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.02]
#  [0.21 0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.34 0.03]
#  [0.66 0.97]]
# ----------------------
# Best validation loss:  0.38709052559550045
# Epoch:  29
# Loss is  0.44768717683455794
# Loss TEST is  0.36430579689932385
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.09]
#  [0.21 0.91]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.45 0.04]
#  [0.55 0.96]]
# ----------------------
# Best validation loss:  0.36430579689932385
# Epoch:  30
# Loss is  0.4317369281813718
# Loss TEST is  0.3763189118791403
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.27]
#  [0.   0.73]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.5  0.04]
#  [0.5  0.96]]
# ----------------------
# Epoch:  31
# Loss is  0.41387400945315617
# Loss TEST is  0.3248371895317289
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.19]
#  [0.   0.81]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.55 0.04]
#  [0.45 0.96]]
# ----------------------
# Best validation loss:  0.3248371895317289
# Epoch:  32
# Loss is  0.39636409282684326
# Loss TEST is  0.2794214997921404
#
# The accuracy in TEST is:
#   1      2      3
# [[0.9  0.02]
#  [0.1  0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.58 0.04]
#  [0.42 0.96]]
# ----------------------
# Best validation loss:  0.2794214997921404
# Epoch:  33
# Loss is  0.3776940641483823
# Loss TEST is  0.27336919649231134
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.09]
#  [0.   0.91]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.59 0.04]
#  [0.41 0.96]]
# ----------------------
# Best validation loss:  0.27336919649231134
# Epoch:  34
# Loss is  0.36124314742099833
# Loss TEST is  0.24008754794502718
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.02]
#  [0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.59 0.04]
#  [0.41 0.96]]
# ----------------------
# Best validation loss:  0.24008754794502718
# Epoch:  35
# Loss is  0.34479363737762836
# Loss TEST is  0.2238051088210038
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.02]
#  [0.   0.98]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.6  0.04]
#  [0.4  0.96]]
# ----------------------
# Best validation loss:  0.2238051088210038
# Epoch:  36
# Loss is  0.3282488074135665
# Loss TEST is  0.1957302240180739
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.6  0.03]
#  [0.4  0.97]]
# ----------------------
# Best validation loss:  0.1957302240180739
# Epoch:  37
# Loss is  0.31023046979005786
# Loss TEST is  0.18303604389847547
#
# The accuracy in TEST is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.64 0.03]
#  [0.36 0.97]]
# ----------------------
# Best validation loss:  0.18303604389847547
# Epoch:  38
# Loss is  0.29225647381106434
# Loss TEST is  0.21082569186017366
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.04]
#  [0.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.66 0.02]
#  [0.34 0.98]]
# ----------------------
# Epoch:  39
# Loss is  0.2682597385224513
# Loss TEST is  0.17633441363801713
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01]
#  [0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.68 0.02]
#  [0.32 0.98]]
# ----------------------
# Best validation loss:  0.17633441363801713
# Epoch:  40
# Loss is  0.25120546398819354
# Loss TEST is  0.18253913496601853
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.68 0.01]
#  [0.32 0.99]]
# ----------------------
# Epoch:  41
# Loss is  0.23651538425741564
# Loss TEST is  0.15742179907777484
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.07]
#  [0.   0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.68 0.01]
#  [0.32 0.99]]
# ----------------------
# Best validation loss:  0.15742179907777484
# Epoch:  42
# Loss is  0.2179236157576819
# Loss TEST is  0.15754861450238453
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.69 0.01]
#  [0.31 0.99]]
# ----------------------
# Epoch:  43
# Loss is  0.20439671548668314
# Loss TEST is  0.17579782483661133
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.7  0.01]
#  [0.3  0.99]]
# ----------------------
# Epoch:  44
# Loss is  0.18858506487331528
# Loss TEST is  0.15967662664820115
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.72 0.01]
#  [0.28 0.99]]
# ----------------------
# Epoch:  45
# Loss is  0.17859636756461023
# Loss TEST is  0.1915115754696371
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.73 0.01]
#  [0.27 0.99]]
# ----------------------
# Epoch:  46
# Loss is  0.16221242585187948
# Loss TEST is  0.2100253894080299
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.8  0.02]
#  [0.2  0.98]]
# ----------------------
# Epoch:  47
# Loss is  0.1501645230224743
# Loss TEST is  0.18617211479976756
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.86 0.01]
#  [0.14 0.99]]
# ----------------------
# Epoch:  48
# Loss is  0.14039198771695008
# Loss TEST is  0.22987506516160952
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.89 0.01]
#  [0.11 0.99]]
# ----------------------
# Epoch:  49
# Loss is  0.12744693063955376
# Loss TEST is  0.21771960692037576
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.01]
#  [0.06 0.99]]
# ----------------------
# Epoch:  50
# Loss is  0.11941043624051527
# Loss TEST is  0.2062694064293178
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.01]
#  [0.06 0.99]]
# ----------------------
# Epoch:  51
# Loss is  0.10860219378258296
# Loss TEST is  0.18825543630504205
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.01]
#  [0.06 0.99]]
# ----------------------
# Epoch:  52
# Loss is  0.1009207560280383
# Loss TEST is  0.21106899448808628
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.01]
#  [0.06 0.99]]
# ----------------------
# Epoch:  53
# Loss is  0.09494670301423845
# Loss TEST is  0.22469084141877074
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.01]
#  [0.06 0.99]]
# ----------------------
# Epoch:  54
# Loss is  0.08880737263727304
# Loss TEST is  0.23036301870289988
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.95 0.01]
#  [0.05 0.99]]
# ----------------------
# Epoch:  55
# Loss is  0.08436492847611651
# Loss TEST is  0.24632440750521975
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.01]
#  [0.06 0.99]]
# ----------------------
# Epoch:  56
# Loss is  0.07810505139439003
# Loss TEST is  0.24029702429892213
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.95 0.  ]
#  [0.05 1.  ]]
# ----------------------
# Epoch:  57
# Loss is  0.07292221699827824
# Loss TEST is  0.25749056352655186
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.94 0.  ]
#  [0.06 1.  ]]
# ----------------------
# Epoch:  58
# Loss is  0.06879979132220221
# Loss TEST is  0.31577703410667446
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.95 0.  ]
#  [0.05 1.  ]]
# ----------------------
# Epoch:  59
# Loss is  0.06606978529857264
# Loss TEST is  0.2730345193013567
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.95 0.  ]
#  [0.05 1.  ]]
# ----------------------
# Epoch:  60
# Loss is  0.06128656754387174
# Loss TEST is  0.26994522350454936
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.95 0.  ]
#  [0.05 1.  ]]
# ----------------------
# Epoch:  61
# Loss is  0.056852880383927176
# Loss TEST is  0.25217142152466304
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.95 0.  ]
#  [0.05 1.  ]]
# ----------------------
# Epoch:  62
# Loss is  0.05279545678536673
# Loss TEST is  0.1946916912712687
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.95 0.  ]
#  [0.05 1.  ]]
# ----------------------
# Epoch:  63
# Loss is  0.04941039090157275
# Loss TEST is  0.2777525826039375
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.96 0.  ]
#  [0.04 1.  ]]
# ----------------------
# Epoch:  64
# Loss is  0.04612249132146798
# Loss TEST is  0.26623307511129557
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.96 0.  ]
#  [0.04 1.  ]]
# ----------------------
# Epoch:  65
# Loss is  0.0433404004012329
# Loss TEST is  0.2228073518255903
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.97 0.  ]
#  [0.03 1.  ]]
# ----------------------
# Epoch:  66
# Loss is  0.039886093325013125
# Loss TEST is  0.2739040818069899
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.98 0.  ]
#  [0.02 1.  ]]
# ----------------------
# Epoch:  67
# Loss is  0.03647002394554084
# Loss TEST is  0.27548343028572125
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.98 0.  ]
#  [0.02 1.  ]]
# ----------------------
# Epoch:  68
# Loss is  0.03400397889882974
# Loss TEST is  0.24209241051253816
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# ----------------------
# Epoch:  69
# Loss is  0.03296769576840067
# Loss TEST is  0.23175040663605326
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.98 0.  ]
#  [0.02 1.  ]]
# ----------------------
# Epoch:  70
# Loss is  0.028412978054622666
# Loss TEST is  0.17078374824750678
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# ----------------------
# Epoch:  71
# Loss is  0.027441209143900497
# Loss TEST is  0.2848632036044349
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# ----------------------
# Epoch:  72
# Loss is  0.026358924410193437
# Loss TEST is  0.23706113726891515
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# ----------------------
# Epoch:  73
# Loss is  0.022955500236194994
# Loss TEST is  0.220192668562928
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# ----------------------
# Epoch:  74
# Loss is  0.021893547660027796
# Loss TEST is  0.2293129012536873
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  75
# Loss is  0.019756402497535238
# Loss TEST is  0.31125696110387474
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  76
# Loss is  0.018035487325835056
# Loss TEST is  0.2264641477834249
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  77
# Loss is  0.017173403467992007
# Loss TEST is  0.2540931172412792
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  78
# Loss is  0.01611808082876178
# Loss TEST is  0.2822204862790917
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  79
# Loss is  0.014689920062946093
# Loss TEST is  0.2614413036715433
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  80
# Loss is  0.014598298451192857
# Loss TEST is  0.26721238049951496
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  81
# Loss is  0.01315728494512808
# Loss TEST is  0.2333763169635321
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  82
# Loss is  0.014365330697847125
# Loss TEST is  0.20707848973277915
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  83
# Loss is  0.010865466602839494
# Loss TEST is  0.22494208842821517
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  84
# Loss is  0.010840009733166204
# Loss TEST is  0.21541524786037022
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  85
# Loss is  0.009946856862001552
# Loss TEST is  0.30058426257004944
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  86
# Loss is  0.010061334888900715
# Loss TEST is  0.21738805075426584
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  87
# Loss is  0.008794112854517979
# Loss TEST is  0.18651598200721012
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  88
# Loss is  0.00823437961736235
# Loss TEST is  0.176603376048935
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  89
# Loss is  0.007372904874992912
# Loss TEST is  0.29630709003962674
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  90
# Loss is  0.00705249591478583
# Loss TEST is  0.20297251220127463
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  91
# Loss is  0.006983234125565161
# Loss TEST is  0.22281704494472374
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  92
# Loss is  0.0060925730234146986
# Loss TEST is  0.2192569075557274
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  93
# Loss is  0.0063603033023719915
# Loss TEST is  0.17926346491845335
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  94
# Loss is  0.0073985349193467324
# Loss TEST is  0.20097877398406833
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  95
# Loss is  0.005601010380784086
# Loss TEST is  0.22508481524792578
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  96
# Loss is  0.005075600822141241
# Loss TEST is  0.19199715533860554
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  97
# Loss is  0.004734536588185238
# Loss TEST is  0.1740791492136892
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  98
# Loss is  0.005216863440661264
# Loss TEST is  0.31674813714768146
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  99
# Loss is  0.0053958355439017005
# Loss TEST is  0.24275444536913632
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  100
# Loss is  0.004370030004599757
# Loss TEST is  0.2025936902034466
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  101
# Loss is  0.004705546740560617
# Loss TEST is  0.17240922848342394
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  102
# Loss is  0.004298719945436812
# Loss TEST is  0.21232704965783053
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  103
# Loss is  0.003796390853209223
# Loss TEST is  0.15932844549217245
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  104
# Loss is  0.003578754789662741
# Loss TEST is  0.14607616601419435
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.14607616601419435
# Epoch:  105
# Loss is  0.004759524613708834
# Loss TEST is  0.17237970982192352
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  106
# Loss is  0.003625593243919286
# Loss TEST is  0.17435736233813393
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  107
# Loss is  0.0030506136546677412
# Loss TEST is  0.29476788020366973
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  108
# Loss is  0.005900547562722693
# Loss TEST is  0.13381762250828746
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.13381762250828746
# Epoch:  109
# Loss is  0.0036160568391751264
# Loss TEST is  0.17777227196562698
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  110
# Loss is  0.005811640432195576
# Loss TEST is  0.24559339277409198
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  111
# Loss is  0.0037213442395812413
# Loss TEST is  0.16183435203003685
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  112
# Loss is  0.002768219155689661
# Loss TEST is  0.1822454039355969
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  113
# Loss is  0.0026674796417293675
# Loss TEST is  0.14333033891580382
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  114
# Loss is  0.002714610323399881
# Loss TEST is  0.02513871293443208
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01]
#  [0.   0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.02513871293443208
# Epoch:  115
# Loss is  0.003226631441154148
# Loss TEST is  0.1387365532157644
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  116
# Loss is  0.0027959570223982963
# Loss TEST is  0.16864469809377897
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  117
# Loss is  0.0027391563452541794
# Loss TEST is  0.12958956668337368
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  118
# Loss is  0.0025761063875836335
# Loss TEST is  0.16848750517251973
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  119
# Loss is  0.0024145163149558286
# Loss TEST is  0.21110686735911194
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  120
# Loss is  0.0026255315999924498
# Loss TEST is  0.22705661641788838
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  121
# Loss is  0.0027114338758778378
# Loss TEST is  0.05905202653592417
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.07]
#  [0.   0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  122
# Loss is  0.0023640989796101038
# Loss TEST is  0.17814638240409472
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  123
# Loss is  0.0032070706184961326
# Loss TEST is  0.1676572609986448
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  124
# Loss is  0.006624942359453796
# Loss TEST is  0.37784656787468673
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  125
# Loss is  0.0031106035172509634
# Loss TEST is  0.13800752716081663
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  126
# Loss is  0.002002880342078625
# Loss TEST is  0.19160548891772183
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  127
# Loss is  0.0016825377605383055
# Loss TEST is  0.1767813752106794
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  128
# Loss is  0.0016582979889421224
# Loss TEST is  0.19126151438265482
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  129
# Loss is  0.0016192084597029999
# Loss TEST is  0.23411117504469925
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  130
# Loss is  0.0015243200337371433
# Loss TEST is  0.11469887156177518
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  131
# Loss is  0.001545996534815823
# Loss TEST is  0.08402195368694457
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.07]
#  [0.   0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  132
# Loss is  0.004187506789682941
# Loss TEST is  0.18689777886672496
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  133
# Loss is  0.0016624872355636407
# Loss TEST is  0.13981745045499278
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  134
# Loss is  0.001590774508386036
# Loss TEST is  0.14094974187922307
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  135
# Loss is  0.002043191990719496
# Loss TEST is  0.25236425107621346
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  136
# Loss is  0.0019338841681933291
# Loss TEST is  0.1409616878814967
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  137
# Loss is  0.0017654736492426274
# Loss TEST is  0.09117295176747246
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  138
# Loss is  0.0013722029492747746
# Loss TEST is  0.12365041586553029
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  139
# Loss is  0.0018915184931677725
# Loss TEST is  0.14129251347166913
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  140
# Loss is  0.002505510917370959
# Loss TEST is  0.140585238783563
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  141
# Loss is  0.0025846616018686953
# Loss TEST is  0.1589243025176308
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  142
# Loss is  0.0016603537986042644
# Loss TEST is  0.10094882038303127
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  143
# Loss is  0.001459101381174436
# Loss TEST is  0.1837287894534385
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  144
# Loss is  0.0016884992189046247
# Loss TEST is  0.09683720587103417
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  145
# Loss is  0.0017961875715794644
# Loss TEST is  0.11769937074385681
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  146
# Loss is  0.002018730892664961
# Loss TEST is  0.10061566209978344
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  147
# Loss is  0.0011355328197652308
# Loss TEST is  0.11563449672581144
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  148
# Loss is  0.001472240256172029
# Loss TEST is  0.08838519995080855
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.07]
#  [0.   0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  149
# Loss is  0.0011810825231576738
# Loss TEST is  0.2767262619092108
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.08]
#  [0.   0.92]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Final Test error Net 6.03% 100/1658
# 525.237553358078

# %%
accuracyTEST = errorsTable()
model = torch.load('../../Models/model_main_another_FFT_binary')

model.eval()
lossValue = 0 
with torch.set_grad_enabled(False):
    for local_batch, local_labels in testing_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
        outputTest = model(local_batch)
        accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
        lossTest = criterion(outputTest, local_labels)
        lossValue += lossTest.item()*local_batch.size(0)
print('Loss TEST is ', lossValue/test_input.size(0))

print("")
print("The accuracy in TEST is: ")
print("  1      2      3   ")
print(accuracyTEST.getStats())
# Out:
# Loss TEST is  0.02513871293443208
#
# The accuracy in TEST is:
#   1      2      3
# [[1.   0.01]
#  [0.   0.99]]

# %%
plt.figure()
plt.plot(np.array(loss_test)/max(loss_test))
plt.plot(np.array(loss_train)/max(loss_train))
