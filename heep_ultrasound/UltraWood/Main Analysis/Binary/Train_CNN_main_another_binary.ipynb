# %%
import torch
import torch.utils.data
import glob
import random
import numpy as np
import pandas as pd
from torch import nn, optim
from torch.nn import functional as F
import time
from torch.nn.utils import weight_norm

# %%
seed = 1995
random.seed(seed)     # python random generator
np.random.seed(seed)  # numpy random generator

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
Fs = 100000

# %%
train_data_torch = torch.load('../../data/databases/train_data_torch_main.pt')
train_targets_torch = torch.load('../../data/databases/train_targets_torch_main.pt')

test_data_torch = torch.load('../../data/databases/valid_data_torch_main.pt')
test_targets_torch = torch.load('../../data/databases/valid_targets_torch_main.pt')

# %%
train_targets_torch[torch.where(train_targets_torch==2)] = 1
test_targets_torch[torch.where(test_targets_torch==2)] = 1

# %%
torch.sum(train_targets_torch==0)
# Out:
# tensor(1905)

# %%
torch.sum(train_targets_torch==1)
# Out:
# tensor(4719)

# %%
torch.sum(train_targets_torch==2)
# Out:
# tensor(0)

# %%
print('Dim Train Data: ', train_data_torch.shape)
print('Dim Train Targets: ', train_targets_torch.shape)
print('Dim Test Data: ', test_data_torch.shape)
print('Dim Train Targets: ', test_targets_torch.shape)
# Out:
# Dim Train Data:  torch.Size([6624, 1, 35000])
# Dim Train Targets:  torch.Size([6624])
# Dim Test Data:  torch.Size([1658, 1, 35000])
# Dim Train Targets:  torch.Size([1658])

# %%
numChannels = 1
numClasses = 2

# %%
import matplotlib.pyplot as plt
i = 100

# %%
plt.plot(train_data_torch.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %% [markdown]
# # This is the formula for computing the size of the output of every layer
#
# $$L_{out} = \frac{L_{in}- Kernel_{size}}{stride}+1$$

# %% [markdown]
# # Here there's and example:
# $input size = 1 * 20'000 * 4 $
#
# after the first convolution:
# $output = \frac{20000-5000}{5}+1 = 3001$
# and the channels go from the initial 4 to the specified 32
#
# after the second convolution:
# $output = \frac{3001-2002}{1}+1 = 1000$
# and the channels go from 32 to 64
#
# after the last convolution:
# $output = \frac{1000-1000}{1}+1 = 1$
# and the channels go from 64 to 5 (as the number of classes!!!)

# %%
(35000-5000)/2+1
# Out:
# 15001.0

# %%
(15001-5000)/2+1
# Out:
# 5001.5

# %%
(5001-4500)/2+1
# Out:
# 251.5

# %%
KERNEL_SIZE = 128
POOL_FACT = 2
STRIDE_FACT = KERNEL_SIZE // 4
CHANNEL_COUNT = 2
use_avg_pool = True
model = torch.nn.Sequential() 
output_dim = 35000
model.append(torch.nn.Conv1d(in_channels = 1, out_channels = CHANNEL_COUNT, kernel_size = KERNEL_SIZE, stride=STRIDE_FACT)) #16x16896 - 512 + 1 
output_dim = (output_dim - KERNEL_SIZE) // STRIDE_FACT + 1
model.append(torch.nn.ReLU()) 
if use_avg_pool:
    model.append(torch.nn.AvgPool1d(POOL_FACT))
else:
    model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
output_dim /= POOL_FACT
model.append(torch.nn.Conv1d(in_channels = CHANNEL_COUNT, out_channels=CHANNEL_COUNT, kernel_size=KERNEL_SIZE // 2, stride=STRIDE_FACT // 2)) #16x7681
output_dim = (output_dim - KERNEL_SIZE // 2) // (STRIDE_FACT // 2)+ 1
model.append(torch.nn.ReLU())
if use_avg_pool:
    model.append(torch.nn.AvgPool1d(POOL_FACT))
else:
    model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
output_dim /= POOL_FACT
model.append(torch.nn.Flatten())
model.append(torch.nn.Linear(in_features = int(output_dim) * CHANNEL_COUNT, out_features = 9))
model.append(torch.nn.ReLU())
model.append(torch.nn.Linear(in_features = 9, out_features = 2))
# Out:
# Sequential(
#   (0): Conv1d(1, 2, kernel_size=(128,), stride=(32,))
#   (1): ReLU()
#   (2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (3): Conv1d(2, 2, kernel_size=(64,), stride=(16,))
#   (4): ReLU()
#   (5): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (6): Flatten(start_dim=1, end_dim=-1)
#   (7): Linear(in_features=30, out_features=9, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=9, out_features=2, bias=True)
# )

# %%
#model, criterion = fastCNN(), nn.CrossEntropyLoss()

# %%
criterion = torch.nn.CrossEntropyLoss()

# %%
def count_parameters(model): return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
count_parameters(model)
# Out:
# 815

# %%
def compute_nb_errors(model, testing_generator):
    nb_errors=0
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            predicted_classes = outputTest.max(1)[1]
            nb_errors += (predicted_classes != local_labels).long().sum()

    return nb_errors

# %%
if (torch.cuda.is_available()):
    model = model.cuda()

# %%
train_input = train_data_torch.view(train_data_torch.size(0), numChannels, -1).float()
train_target = train_targets_torch.long().view(-1)
test_input = test_data_torch.view(test_data_torch.size(0), numChannels, -1).float()
test_target = test_targets_torch.long().view(-1)

# %%
train_input.shape
# Out:
# torch.Size([6624, 1, 35000])

# %%
train_input = (train_input-torch.mean(train_input,2,keepdim=True))
test_input = (test_input-torch.mean(test_input,2,keepdim=True))

# %%
train_input = train_input/torch.max(train_input,2,keepdim=True)[0]
test_input = test_input/torch.max(test_input,2,keepdim=True)[0]

# %%
plt.plot(train_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
plt.plot(test_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
train_input.narrow(0, 0, 2).shape
# Out:
# torch.Size([2, 1, 35000])

# %%
out = model(train_input.narrow(0, 0, 2).cuda())
out.shape
# Out:
# torch.Size([2, 2])

# %%
lr = 3e-4

# %%
optimizer = optim.Adam(model.parameters(), lr = lr) #, weight_decay=1e-5)
nb_epochs = 150
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', verbose=True, factor=0.2, patience = 30)

# %%
class errorsTable():
    def __init__(self):
        self.accuracyMatr = np.zeros((numClasses,numClasses))
    def newEntry(self,predictions,groundTruths):
        for pred,tru in zip(predictions,groundTruths):
            #print(pred, tru)
            self.accuracyMatr[pred,tru]+=1
    def getStats(self):
        #print(self.accuracyMatr)
        numEntry = np.sum(self.accuracyMatr,0)
        resultMatr = self.accuracyMatr/numEntry
        return resultMatr

# %%
np.set_printoptions(precision=2, suppress=True)

# %%
batch_size_train = 32
batch_size_test = 1000

# %%
#torch.backends.cudnn.enabled = False

# %%
training_set = torch.utils.data.TensorDataset(train_input, train_target)
testing_set = torch.utils.data.TensorDataset(test_input, test_target)

# %%
# Generators
training_generator = torch.utils.data.DataLoader(training_set, batch_size=batch_size_train, num_workers=0,
                                                shuffle=True, drop_last=True)
testing_generator = torch.utils.data.DataLoader(testing_set, batch_size=batch_size_test, num_workers=0,
                                                 shuffle=False, drop_last=False)

# %%
loss_train = []
loss_test = []

t = time.time()

# initialize best validation loss and best model
best_val_loss = float("inf")
best_model = None

for k in range (nb_epochs):
    
    # Create a new error table
    accuracyTRAIN = errorsTable()
    accuracyTEST = errorsTable()
    print('Epoch: ', k)
    model.train()

    lossValue = 0
    for local_batch, local_labels in training_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()       
        model.zero_grad()
        output = model(local_batch)
        accuracyTRAIN.newEntry(output.max(1)[1], local_labels)
        loss = criterion(output, local_labels)
        lossValue += loss.item()*local_batch.size(0)
        loss.backward()
        optimizer.step()
    scheduler.step(lossValue/train_input.size(0))
    print('Loss is ', lossValue/train_input.size(0))
    loss_train.append(lossValue/train_input.size(0))    
    ################################################################    
    model.eval()
    lossValue = 0 
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
            lossTest = criterion(outputTest, local_labels)
            lossValue += lossTest.item()*local_batch.size(0)
    val_loss = lossValue/test_input.size(0)
    print('Validation Loss is ', val_loss)
    loss_test.append(val_loss)
    print("")
    print("The accuracy in TEST is: ")
    print("  1      2      3   ")
    print(accuracyTEST.getStats())
    print("The accuracy in TRAIN is: ")
    print("  1      2      3   ")
    print(accuracyTRAIN.getStats())
    print("----------------------") 
    
    # check if validation loss has decreased
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        print('Best validation loss: ', best_val_loss)
        best_model = model
        torch.save(best_model, '../../Models/model_main_another_binary')

nb_test_errors = compute_nb_errors(model, testing_generator)  
print('Final Test error Net {:0.2f}% {:d}/{:d}'.format((100 * nb_test_errors) / test_input.size(0),
                                                  nb_test_errors, test_input.size(0)))
# Out:
# Epoch:  0
# Loss is  0.6793620910333551
# Validation Loss is  0.5978590681771462
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.49 0.51]
#  [0.51 0.49]]
# ----------------------
# Best validation loss:  0.5978590681771462
# Epoch:  1
# Loss is  0.5987170532993649
# Validation Loss is  0.5956000919005552
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5956000919005552
# Epoch:  2
# Loss is  0.595134282025738
# Validation Loss is  0.590681826140826
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.590681826140826
# Epoch:  3
# Loss is  0.5901342545442535
# Validation Loss is  0.5844521197895952
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5844521197895952
# Epoch:  4
# Loss is  0.5791678928234727
# Validation Loss is  0.5713344061762922
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5713344061762922
# Epoch:  5
# Loss is  0.5613189356914465
# Validation Loss is  0.5484259611015873
#
# The accuracy in TEST is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0. 0.]
#  [1. 1.]]
# ----------------------
# Best validation loss:  0.5484259611015873
# Epoch:  6
# Loss is  0.5258749641370082
# Validation Loss is  0.5181108592718444
#
# The accuracy in TEST is:
#   1      2      3
# [[0.   0.04]
#  [1.   0.96]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.07 0.  ]
#  [0.93 1.  ]]
# ----------------------
# Best validation loss:  0.5181108592718444
# Epoch:  7
# Loss is  0.47670137522301237
# Validation Loss is  0.48033409512661335
#
# The accuracy in TEST is:
#   1      2      3
# [[0.   0.06]
#  [1.   0.94]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.27 0.02]
#  [0.73 0.98]]
# ----------------------
# Best validation loss:  0.48033409512661335
# Epoch:  8
# Loss is  0.41846459088982013
# Validation Loss is  0.44615634114664626
#
# The accuracy in TEST is:
#   1      2      3
# [[0.42 0.07]
#  [0.58 0.93]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.38 0.04]
#  [0.62 0.96]]
# ----------------------
# Best validation loss:  0.44615634114664626
# Epoch:  9
# Loss is  0.35149419854804514
# Validation Loss is  0.39921772152868484
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.01]
#  [0.21 0.99]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.63 0.05]
#  [0.37 0.95]]
# ----------------------
# Best validation loss:  0.39921772152868484
# Epoch:  10
# Loss is  0.2883742900142347
# Validation Loss is  0.35263403577885094
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.75 0.06]
#  [0.25 0.94]]
# ----------------------
# Best validation loss:  0.35263403577885094
# Epoch:  11
# Loss is  0.2389905769827861
# Validation Loss is  0.285232311476413
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.82 0.06]
#  [0.18 0.94]]
# ----------------------
# Best validation loss:  0.285232311476413
# Epoch:  12
# Loss is  0.20386555978065526
# Validation Loss is  0.2385289585274005
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.85 0.06]
#  [0.15 0.94]]
# ----------------------
# Best validation loss:  0.2385289585274005
# Epoch:  13
# Loss is  0.1741776540155572
# Validation Loss is  0.1909853933588012
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.89 0.06]
#  [0.11 0.94]]
# ----------------------
# Best validation loss:  0.1909853933588012
# Epoch:  14
# Loss is  0.1470155201240438
# Validation Loss is  0.15559716109271793
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.92 0.06]
#  [0.08 0.94]]
# ----------------------
# Best validation loss:  0.15559716109271793
# Epoch:  15
# Loss is  0.12244605816504806
# Validation Loss is  0.14212612342201758
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.96 0.05]
#  [0.04 0.95]]
# ----------------------
# Best validation loss:  0.14212612342201758
# Epoch:  16
# Loss is  0.10032847384215841
# Validation Loss is  0.10574470881925417
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[0.98 0.04]
#  [0.02 0.96]]
# ----------------------
# Best validation loss:  0.10574470881925417
# Epoch:  17
# Loss is  0.08060520406866419
# Validation Loss is  0.10581523340882956
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.02]
#  [0.   0.98]]
# ----------------------
# Epoch:  18
# Loss is  0.06443521504600842
# Validation Loss is  0.07756582823715681
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1.   0.01]
#  [0.   0.99]]
# ----------------------
# Best validation loss:  0.07756582823715681
# Epoch:  19
# Loss is  0.05077538815673423
# Validation Loss is  0.07740865384461078
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.07740865384461078
# Epoch:  20
# Loss is  0.04033432073063321
# Validation Loss is  0.08412963611189506
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  21
# Loss is  0.03198567648521728
# Validation Loss is  0.07504062361754611
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.07504062361754611
# Epoch:  22
# Loss is  0.02565071775447487
# Validation Loss is  0.06150939266126607
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.06150939266126607
# Epoch:  23
# Loss is  0.02065950415911522
# Validation Loss is  0.0723341398471371
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  24
# Loss is  0.016742044380429574
# Validation Loss is  0.06487904279633223
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  25
# Loss is  0.013614260575819563
# Validation Loss is  0.055719951462041055
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.055719951462041055
# Epoch:  26
# Loss is  0.011216960886745278
# Validation Loss is  0.05818103305069759
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  27
# Loss is  0.009387078351939575
# Validation Loss is  0.0626243147527208
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  28
# Loss is  0.007806581852210749
# Validation Loss is  0.0751498672926958
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  29
# Loss is  0.006563692695600687
# Validation Loss is  0.06258211763905962
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  30
# Loss is  0.005542374498903715
# Validation Loss is  0.06830803144934382
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  31
# Loss is  0.0046820293432596515
# Validation Loss is  0.056848438804917516
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  32
# Loss is  0.004060238848917258
# Validation Loss is  0.06769328364884465
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  33
# Loss is  0.0034785631049766346
# Validation Loss is  0.053770407351279866
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.053770407351279866
# Epoch:  34
# Loss is  0.0030366358524953254
# Validation Loss is  0.06596887050549285
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  35
# Loss is  0.0026053150672609537
# Validation Loss is  0.06305270832575705
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  36
# Loss is  0.002280624790324105
# Validation Loss is  0.06773055360997399
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  37
# Loss is  0.002003994886060403
# Validation Loss is  0.07408717730328603
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  38
# Loss is  0.0017383170356593829
# Validation Loss is  0.06016528711567742
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  39
# Loss is  0.001541243671638675
# Validation Loss is  0.0733406732467748
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  40
# Loss is  0.0013527483166170706
# Validation Loss is  0.04629332023539071
#
# The accuracy in TEST is:
#   1      2      3
# [[0.91 0.  ]
#  [0.09 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.04629332023539071
# Epoch:  41
# Loss is  0.0012202566419418784
# Validation Loss is  0.07198481457656197
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  42
# Loss is  0.0010762671963367972
# Validation Loss is  0.05060083250120839
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  43
# Loss is  0.0009584406065020107
# Validation Loss is  0.062462663028582444
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  44
# Loss is  0.0009030765294381934
# Validation Loss is  0.07333593591778069
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  45
# Loss is  0.0007267138254253704
# Validation Loss is  0.06530278784518363
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  46
# Loss is  0.0006634329345765082
# Validation Loss is  0.0633940324816399
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  47
# Loss is  0.0005790505243734129
# Validation Loss is  0.07445103630189873
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  48
# Loss is  0.0005231893700893388
# Validation Loss is  0.09659369719474249
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  49
# Loss is  0.00047836225157308926
# Validation Loss is  0.08576172965930368
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  50
# Loss is  0.0003986695424160371
# Validation Loss is  0.058670219730482455
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  51
# Loss is  0.0003712337714991676
# Validation Loss is  0.027651933353254964
#
# The accuracy in TEST is:
#   1      2      3
# [[0.98 0.  ]
#  [0.02 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.027651933353254964
# Epoch:  52
# Loss is  0.00034078626371068083
# Validation Loss is  0.06108055787724954
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  53
# Loss is  0.0002923489193325741
# Validation Loss is  0.060432365364131074
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  54
# Loss is  0.0002707362249750894
# Validation Loss is  0.09421803882239956
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  55
# Loss is  0.00022460106244408593
# Validation Loss is  0.05251864351071552
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  56
# Loss is  0.00020461559062015213
# Validation Loss is  0.07202655713290732
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  57
# Loss is  0.00019891809066560723
# Validation Loss is  0.07087345132817693
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  58
# Loss is  0.00017388676733301855
# Validation Loss is  0.06520706714457856
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  59
# Loss is  0.00015081456867275828
# Validation Loss is  0.051901546467558464
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  60
# Loss is  0.0001292168158017929
# Validation Loss is  0.05844224234469981
#
# The accuracy in TEST is:
#   1      2      3
# [[0.86 0.  ]
#  [0.14 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  61
# Loss is  0.00014413062228484064
# Validation Loss is  0.09868296200748806
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  62
# Loss is  0.00010972069630600824
# Validation Loss is  0.0918670984387254
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  63
# Loss is  9.695985054481687e-05
# Validation Loss is  0.045616797446773195
#
# The accuracy in TEST is:
#   1      2      3
# [[0.91 0.  ]
#  [0.09 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  64
# Loss is  9.289884734235182e-05
# Validation Loss is  0.05739371900966861
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.  ]
#  [0.13 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  65
# Loss is  7.920165963709671e-05
# Validation Loss is  0.0805681850873518
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  66
# Loss is  7.304462006348348e-05
# Validation Loss is  0.06422520330034205
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  67
# Loss is  6.414813141537192e-05
# Validation Loss is  0.06866620844106479
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  68
# Loss is  5.740199894233773e-05
# Validation Loss is  0.07632364468386148
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  69
# Loss is  5.448875878935785e-05
# Validation Loss is  0.0654740289428841
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  70
# Loss is  4.849923832210147e-05
# Validation Loss is  0.07132238272770754
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  71
# Loss is  4.1925333244731685e-05
# Validation Loss is  0.05376529587551825
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  72
# Loss is  3.508686479661897e-05
# Validation Loss is  0.08770780810868352
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  73
# Loss is  3.523785899496811e-05
# Validation Loss is  0.07217269028627973
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  74
# Loss is  3.042746467267776e-05
# Validation Loss is  0.03793505880761492
#
# The accuracy in TEST is:
#   1      2      3
# [[0.94 0.  ]
#  [0.06 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  75
# Loss is  2.7686524717776938e-05
# Validation Loss is  0.0743813816327669
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  76
# Loss is  2.655291946255883e-05
# Validation Loss is  0.11795130778279322
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  77
# Loss is  2.155746220844464e-05
# Validation Loss is  0.07704344424177567
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  78
# Loss is  1.9967099887064498e-05
# Validation Loss is  0.05335126217764738
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  79
# Loss is  1.8455028841283246e-05
# Validation Loss is  0.01988068290180622
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Best validation loss:  0.01988068290180622
# Epoch:  80
# Loss is  1.9453665937331773e-05
# Validation Loss is  0.07407182319352652
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  81
# Loss is  1.4739851326449546e-05
# Validation Loss is  0.06809990942945526
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  82
# Loss is  1.4994811822098331e-05
# Validation Loss is  0.06341237004113859
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  83
# Loss is  1.2147221202876124e-05
# Validation Loss is  0.08836279334039826
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  84
# Loss is  1.08200392974426e-05
# Validation Loss is  0.05651156670797001
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  85
# Loss is  9.9461155299e-06
# Validation Loss is  0.05952223267212996
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.  ]
#  [0.13 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  86
# Loss is  8.358688597177712e-06
# Validation Loss is  0.08334613296644823
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  87
# Loss is  7.94596434985394e-06
# Validation Loss is  0.10749322247879065
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  88
# Loss is  8.019371040263474e-06
# Validation Loss is  0.06787313686277092
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  89
# Loss is  7.764309507222601e-06
# Validation Loss is  0.0812133432009827
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  90
# Loss is  6.10276002114054e-06
# Validation Loss is  0.038797865016217396
#
# The accuracy in TEST is:
#   1      2      3
# [[0.94 0.  ]
#  [0.06 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  91
# Loss is  4.80379125125569e-06
# Validation Loss is  0.0851842701453064
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  92
# Loss is  5.249737088816155e-06
# Validation Loss is  0.06403498736236006
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.  ]
#  [0.15 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  93
# Loss is  5.470109646909546e-06
# Validation Loss is  0.06983840920309681
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  94
# Loss is  4.046475553472508e-06
# Validation Loss is  0.08273946526218812
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  95
# Loss is  3.628638020800193e-06
# Validation Loss is  0.09344615365757154
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  96
# Loss is  3.6439243531375447e-06
# Validation Loss is  0.07500121536674775
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  97
# Loss is  2.796393853069882e-06
# Validation Loss is  0.08542609619217126
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  98
# Loss is  3.2099610076985314e-06
# Validation Loss is  0.09315456991028873
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  99
# Loss is  2.517190989582766e-06
# Validation Loss is  0.05670520858288674
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  100
# Loss is  2.0531945801080466e-06
# Validation Loss is  0.10295925405330336
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  101
# Loss is  2.0493274671958135e-06
# Validation Loss is  0.09257829908295045
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  102
# Loss is  1.6793476516600116e-06
# Validation Loss is  0.06904457938218146
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  103
# Loss is  1.5290917703726815e-06
# Validation Loss is  0.09000717027088126
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  104
# Loss is  1.532488329653428e-06
# Validation Loss is  0.08433434595460627
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  105
# Loss is  1.2794573487426445e-06
# Validation Loss is  0.062261046587845675
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.  ]
#  [0.13 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  106
# Loss is  1.3221116724185527e-06
# Validation Loss is  0.062487061127606866
#
# The accuracy in TEST is:
#   1      2      3
# [[0.87 0.  ]
#  [0.13 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  107
# Loss is  1.5346892700345292e-06
# Validation Loss is  0.10638081081957523
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  108
# Loss is  9.738264061294446e-07
# Validation Loss is  0.05169384332488328
#
# The accuracy in TEST is:
#   1      2      3
# [[0.89 0.  ]
#  [0.11 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  109
# Loss is  8.5568761422303e-07
# Validation Loss is  0.07082369188419728
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  110
# Loss is  7.697162830331895e-07
# Validation Loss is  0.10625164359987717
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  111
# Loss is  7.939262552373043e-07
# Validation Loss is  0.0338453477556369
#
# The accuracy in TEST is:
#   1      2      3
# [[0.95 0.  ]
#  [0.05 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  112
# Loss is  6.251095973048676e-07
# Validation Loss is  0.055379963135043446
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  113
# Loss is  5.738201682617634e-07
# Validation Loss is  0.10322909121849856
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  114
# Loss is  5.937313801187271e-07
# Validation Loss is  0.09587104740778414
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  115
# Loss is  5.357491987522632e-07
# Validation Loss is  0.09989137543124946
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  116
# Loss is  4.778052068953251e-07
# Validation Loss is  0.060726876991865
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  117
# Loss is  4.189093040675125e-07
# Validation Loss is  0.06738750103622927
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.  ]
#  [0.15 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  118
# Loss is  3.434204286828153e-07
# Validation Loss is  0.07459075393916902
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  119
# Loss is  3.8922771602021685e-07
# Validation Loss is  0.10864683886848399
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  120
# Loss is  3.406451644732832e-07
# Validation Loss is  0.07870100766636062
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  121
# Loss is  2.6033212009087066e-07
# Validation Loss is  0.06946088502181309
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  122
# Loss is  2.9736464394455e-07
# Validation Loss is  0.10222962016938535
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  123
# Loss is  2.8258759723857907e-07
# Validation Loss is  0.05609922099350732
#
# The accuracy in TEST is:
#   1      2      3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  124
# Loss is  1.8161941458436872e-07
# Validation Loss is  0.08514823755575175
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  125
# Loss is  1.6034761812053572e-07
# Validation Loss is  0.13651782574426424
#
# The accuracy in TEST is:
#   1      2      3
# [[0.79 0.  ]
#  [0.21 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  126
# Loss is  1.583675348991554e-07
# Validation Loss is  0.10583670937037151
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  127
# Loss is  1.530217865184283e-07
# Validation Loss is  0.08345254428855473
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  128
# Loss is  1.1955026051668223e-07
# Validation Loss is  0.07156704959377592
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  129
# Loss is  1.2563234852436267e-07
# Validation Loss is  0.07859090029006988
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  130
# Loss is  1.3981306601244393e-07
# Validation Loss is  0.04008810995517364
#
# The accuracy in TEST is:
#   1      2      3
# [[0.93 0.  ]
#  [0.07 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  131
# Loss is  8.663501593843759e-08
# Validation Loss is  0.07639279665000763
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  132
# Loss is  1.0133750087809295e-07
# Validation Loss is  0.09054509344520845
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  133
# Loss is  7.653894342902317e-08
# Validation Loss is  0.1149429557946105
#
# The accuracy in TEST is:
#   1      2      3
# [[0.8 0. ]
#  [0.2 1. ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  134
# Loss is  7.988589635317327e-08
# Validation Loss is  0.02430920284443655
#
# The accuracy in TEST is:
#   1      2      3
# [[0.98 0.  ]
#  [0.02 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  135
# Loss is  7.283172778130139e-08
# Validation Loss is  0.09972074275568972
#
# The accuracy in TEST is:
#   1      2      3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  136
# Loss is  6.48591196574284e-08
# Validation Loss is  0.07515261959468786
#
# The accuracy in TEST is:
#   1      2      3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  137
# Loss is  5.236958643229461e-08
# Validation Loss is  0.0707030810586506
#
# The accuracy in TEST is:
#   1      2      3
# [[0.85 0.  ]
#  [0.15 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  138
# Loss is  7.018589433524607e-08
# Validation Loss is  0.08807723447950096
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  139
# Loss is  4.2597679750716357e-08
# Validation Loss is  0.09462464756284031
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  140
# Loss is  4.7780591842707105e-08
# Validation Loss is  0.08132588474217024
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  141
# Loss is  4.472118197609105e-08
# Validation Loss is  0.08240599009074694
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  142
# Loss is  2.8128571491360725e-08
# Validation Loss is  0.09143556455831045
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  143
# Loss is  2.9802115521501786e-08
# Validation Loss is  0.09109316287231962
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  144
# Loss is  2.7966564717288538e-08
# Validation Loss is  0.09325998854363927
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  145
# Loss is  2.4259256923201083e-08
# Validation Loss is  0.09568879439689858
#
# The accuracy in TEST is:
#   1      2      3
# [[0.82 0.  ]
#  [0.18 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  146
# Loss is  2.0174108891218656e-08
# Validation Loss is  0.08386302335846123
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  147
# Loss is  2.8362448787848777e-08
# Validation Loss is  0.08321135334751431
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  148
# Loss is  2.2117679884039003e-08
# Validation Loss is  0.08790406744715963
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  149
# Loss is  1.2669567404861195e-08
# Validation Loss is  0.09080480813836303
#
# The accuracy in TEST is:
#   1      2      3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1      2      3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Final Test error Net 5.01% 83/1658

# %%
accuracyTEST = errorsTable()
model = torch.load('../../Models/model_main_another_binary') 


model.eval()
lossValue = 0 
with torch.set_grad_enabled(False):
    for local_batch, local_labels in testing_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
        outputTest = model(local_batch)
        accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
        lossTest = criterion(outputTest, local_labels)
        lossValue += lossTest.item()*local_batch.size(0)
print('Loss TEST is ', lossValue/test_input.size(0))

print("")
print("The accuracy in TEST is: ")
print("  1      2      3   ")
print(accuracyTEST.getStats())
# Out:
# Loss TEST is  0.01988068290180622
#
# The accuracy in TEST is:
#   1      2      3
# [[0.99 0.  ]
#  [0.01 1.  ]]

# %%
plt.figure()
plt.plot(np.array(loss_test)/max(loss_test))
plt.plot(np.array(loss_train)/max(loss_train))
