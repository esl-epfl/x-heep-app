# %%
import torch
import torch.utils.data
import glob
import random
import numpy as np
import pandas as pd
from torch import nn, optim
from torch.nn import functional as F
import time
from torch.nn.utils import weight_norm

# %%
seed = 1995
random.seed(seed)     # python random generator
np.random.seed(seed)  # numpy random generator

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
train_data_torch = torch.load('./data torch/train_data_torch_newADV.pt')
train_targets_torch = torch.load('./data torch/train_targets_torch_newADV.pt')

test_data_torch = torch.load('./data torch/test_data_torch_newADV.pt')
test_targets_torch = torch.load('./data torch/test_targets_torch_newADV.pt')

# %%
print('Dim Train Data: ', train_data_torch.shape)
print('Dim Train Targets: ', train_targets_torch.shape)
print('Dim Test Data: ', test_data_torch.shape)
print('Dim Train Targets: ', test_targets_torch.shape)
# Out:
# Dim Train Data:  torch.Size([10015, 1, 35000])
# Dim Train Targets:  torch.Size([10015])
# Dim Test Data:  torch.Size([2507, 1, 35000])
# Dim Train Targets:  torch.Size([2507])

# %%
numChannels = 1
numClasses = 3

# %%
import matplotlib.pyplot as plt
i = 100

# %%
plt.plot(train_data_torch.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %% [markdown]
# # This is the formula for computing the size of the output of every layer
#
# $$L_{out} = \frac{L_{in}- Kernel_{size}}{stride}+1$$

# %% [markdown]
# # Here there's and example:
# $input size = 1 * 20'000 * 4 $
#
# after the first convolution:
# $output = \frac{20000-5000}{5}+1 = 3001$
# and the channels go from the initial 4 to the specified 32
#
# after the second convolution:
# $output = \frac{3001-2002}{1}+1 = 1000$
# and the channels go from 32 to 64
#
# after the last convolution:
# $output = \frac{1000-1000}{1}+1 = 1$
# and the channels go from 64 to 5 (as the number of classes!!!)

# %%
(35000-5000)/2+1
# Out:
# 15001.0

# %%
(15001-5000)/2+1
# Out:
# 5001.5

# %%
(5001-4500)/2+1
# Out:
# 251.5

# %%
class fastCNN(nn.Module): 
    def __init__(self):
        super(fastCNN, self).__init__()
        self.conv = nn.Conv1d(numChannels, 2, kernel_size=5000, stride=2) 
        self.bn = nn.BatchNorm1d(2) #15001
        self.conv2 = nn.Conv1d(2, 2, kernel_size=5000, stride=2)
        self.bn2 = nn.BatchNorm1d(2) #5001
        self.conv3 = nn.Conv1d(2, 2, kernel_size=4500, stride=2)
        self.bn3 = nn.BatchNorm1d(2) #251
        self.conv4 = nn.Conv1d(2, numClasses, kernel_size=251)
                
    def forward(self, x):
        x = F.relu(self.bn(self.conv(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.conv4(x)
        x = x.view(-1, numClasses)
        return x

# %%
KERNEL_SIZE = 64
POOL_FACT = 2
STRIDE_FACT = KERNEL_SIZE // 4
CHANNEL_COUNT = 16
use_avg_pool = True
model = torch.nn.Sequential() 
output_dim = 35000
model.append(torch.nn.Conv1d(in_channels = 1, out_channels = CHANNEL_COUNT, kernel_size = KERNEL_SIZE, stride=STRIDE_FACT)) #16x16896 - 512 + 1 
output_dim = (output_dim - KERNEL_SIZE) // STRIDE_FACT + 1
model.append(torch.nn.ReLU()) 
if use_avg_pool:
    model.append(torch.nn.AvgPool1d(POOL_FACT))
else:
    model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
output_dim /= POOL_FACT
model.append(torch.nn.Conv1d(in_channels = CHANNEL_COUNT, out_channels=CHANNEL_COUNT, kernel_size=KERNEL_SIZE // 2, stride=STRIDE_FACT // 2)) #16x7681
output_dim = (output_dim - KERNEL_SIZE // 2) // (STRIDE_FACT // 2)+ 1
model.append(torch.nn.ReLU())
if use_avg_pool:
    model.append(torch.nn.AvgPool1d(POOL_FACT))
else:
    model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
output_dim /= POOL_FACT
model.append(torch.nn.Flatten())
model.append(torch.nn.Linear(in_features = int(output_dim) * CHANNEL_COUNT, out_features = 9))
model.append(torch.nn.ReLU())
model.append(torch.nn.Linear(in_features = 9, out_features = numClasses))
# Out:
# Sequential(
#   (0): Conv1d(1, 16, kernel_size=(64,), stride=(16,))
#   (1): ReLU()
#   (2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (3): Conv1d(16, 16, kernel_size=(32,), stride=(8,))
#   (4): ReLU()
#   (5): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (6): Flatten(start_dim=1, end_dim=-1)
#   (7): Linear(in_features=1056, out_features=9, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=9, out_features=3, bias=True)
# )

# %%
def count_parameters(model): return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def compute_nb_errors(model, testing_generator):
    nb_errors=0
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            predicted_classes = outputTest.max(1)[1]
            nb_errors += (predicted_classes != local_labels).long().sum()

    return nb_errors

# %%
model, criterion = fastCNN(), nn.CrossEntropyLoss()

# %%
count_parameters(model)
# Out:
# 49527

# %%
criterion = nn.CrossEntropyLoss()

# %%
if (torch.cuda.is_available()):
    model = model.cuda()

# %%
train_input = train_data_torch.view(train_data_torch.size(0), numChannels, -1).float()/4096.0
train_target = train_targets_torch.long().view(-1)
test_input = test_data_torch.view(test_data_torch.size(0), numChannels, -1).float()/4096.0
test_target = test_targets_torch.long().view(-1)

# %%
plt.plot(train_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
plt.plot(test_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
train_input.narrow(0, 0, 2).shape
# Out:
# torch.Size([2, 1, 35000])

# %%
out = model(train_input.narrow(0, 0, 2).cuda())
out.shape
# Out:
# torch.Size([2, 3])

# %%
lr = 3e-3

# %%
optimizer = optim.Adam(model.parameters(), lr = lr)
nb_epochs = 50
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', verbose=True, factor=0.2, patience = 30)

# %%
class errorsTable():
    def __init__(self):
        self.accuracyMatr = np.zeros((numClasses,numClasses))
    def newEntry(self,predictions,groundTruths):
        for pred,tru in zip(predictions,groundTruths):
            #print(pred, tru)
            self.accuracyMatr[pred,tru]+=1
    def getStats(self):
        #print(self.accuracyMatr)
        numEntry = np.sum(self.accuracyMatr,0)
        resultMatr = self.accuracyMatr/numEntry
        return resultMatr

# %%
np.set_printoptions(precision=2, suppress=True)

# %%
batch_size_train = 2000
batch_size_test = 1000

# %%
#torch.backends.cudnn.enabled = False

# %%
training_set = torch.utils.data.TensorDataset(train_input, train_target)
testing_set = torch.utils.data.TensorDataset(test_input, test_target)

# %%
# Generators
training_generator = torch.utils.data.DataLoader(training_set, batch_size=batch_size_train, num_workers=0,
                                                shuffle=True, drop_last=True)
testing_generator = torch.utils.data.DataLoader(testing_set, batch_size=batch_size_test, num_workers=0,
                                                 shuffle=False, drop_last=False)

# %%
loss_train = []
loss_test = []

t = time.time()
for k in range (nb_epochs):
    
    # Create a new error table
    accuracyTRAIN = errorsTable()
    accuracyTEST = errorsTable()
    print('Epoch: ', k)
    model.train()

    lossValue = 0
    for local_batch, local_labels in training_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()       
        model.zero_grad()
        output = model(local_batch)
        accuracyTRAIN.newEntry(output.max(1)[1], local_labels)
        loss = criterion(output, local_labels)
        lossValue += loss.item()*local_batch.size(0)
        loss.backward()
        optimizer.step()
    scheduler.step(lossValue/train_input.size(0))
    print('Loss is ', lossValue/train_input.size(0))
    loss_train.append(lossValue/train_input.size(0))    
    ################################################################    
    model.eval()
    lossValue = 0 
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
            lossTest = criterion(outputTest, local_labels)
            lossValue += lossTest.item()*local_batch.size(0)
    print('Loss TEST is ', lossValue/test_input.size(0))
    loss_test.append(lossValue/test_input.size(0))
    print("")
    print("The accuracy in TEST is: ")
    print("  1    2    3   ")
    print(accuracyTEST.getStats())
    print("The accuracy in TRAIN is: ")
    print("  1    2    3   ")
    print(accuracyTRAIN.getStats())
    print("----------------------")
    if k%10 == 0:
        #nb_test_errors = compute_nb_errors(model, test_input, test_target, batch_size_test)

        #print(k, ': Test accuracy Net {:0.2f}%% {:d}/{:d}'.format(100-(100 * nb_test_errors) / test_input.size(0),
                                                     #nb_test_errors, test_input.size(0)))
        

        #nb_train_errors = compute_nb_errors(model, train_input, train_target, batch_size_train)

        #print(k, ': Train accuracy Net {:0.2f}%% {:d}/{:d}'.format(100-(100 * nb_train_errors) / train_input.size(0),
                                                          #nb_train_errors, train_input.size(0)))
        print("Hey! Ten epochs are passed! We are getting older")
        
        


nb_test_errors = compute_nb_errors(model, testing_generator)  
print('Final Test error Net {:0.2f}% {:d}/{:d}'.format((100 * nb_test_errors) / test_input.size(0),
                                                  nb_test_errors, test_input.size(0)))

elapsed = time.time() - t
print(elapsed)
# Out:
# Epoch:  0
# Loss is  1.2883014936061483
# Loss TEST is  1.8580604495757786
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.2 0.2 0.2]
#  [0.4 0.4 0.4]
#  [0.4 0.4 0.4]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  1
# Loss is  1.0906033318339141
# Loss TEST is  1.1767664167288532
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.54 0.5  0.46]
#  [0.4  0.4  0.4 ]
#  [0.06 0.1  0.14]]
# ----------------------
# Epoch:  2
# Loss is  1.051088148394169
# Loss TEST is  1.442538453553557
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.43 0.33 0.15]
#  [0.34 0.35 0.25]
#  [0.23 0.32 0.6 ]]
# ----------------------
# Epoch:  3
# Loss is  1.0030502089844664
# Loss TEST is  5.028637297994752
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.61 0.55 0.2 ]
#  [0.16 0.25 0.04]
#  [0.23 0.2  0.76]]
# ----------------------
# Epoch:  4
# Loss is  0.9164948970510909
# Loss TEST is  26.263965474308655
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.6  0.41 0.17]
#  [0.22 0.34 0.04]
#  [0.17 0.25 0.79]]
# ----------------------
# Epoch:  5
# Loss is  0.7603168249487341
# Loss TEST is  134.39951448931274
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.89 0.72 0.17]
#  [0.11 0.21 0.04]
#  [0.   0.07 0.79]]
# ----------------------
# Epoch:  6
# Loss is  0.593811181326003
# Loss TEST is  495.0073023074454
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.94 0.38 0.  ]
#  [0.06 0.62 0.18]
#  [0.   0.   0.82]]
# ----------------------
# Epoch:  7
# Loss is  0.47722782900615507
# Loss TEST is  1144.6434115336433
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1.   0.49 0.  ]
#  [0.   0.5  0.  ]
#  [0.   0.01 1.  ]]
# ----------------------
# Epoch:  8
# Loss is  0.42086486154595315
# Loss TEST is  1754.9450406050557
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.96 0.43 0.  ]
#  [0.04 0.57 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  9
# Loss is  0.3737338054674123
# Loss TEST is  2157.9397024269547
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1.   0.47 0.  ]
#  [0.   0.53 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  10
# Loss is  0.3207505731301729
# Loss TEST is  2607.5104940541482
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.98 0.44 0.  ]
#  [0.02 0.56 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  11
# Loss is  0.2721528023764067
# Loss TEST is  2781.9838339368516
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.99 0.26 0.  ]
#  [0.01 0.74 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  12
# Loss is  0.19799089705533404
# Loss TEST is  2932.2844765126397
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.99 0.17 0.  ]
#  [0.01 0.83 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  13
# Loss is  0.12308055171357116
# Loss TEST is  2885.536756846455
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1.   0.06 0.  ]
#  [0.   0.94 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  14
# Loss is  0.08356004759959441
# Loss TEST is  2414.012201383003
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1.   0.01 0.  ]
#  [0.   0.99 0.  ]
#  [0.   0.   1.  ]]
# ----------------------
# Epoch:  15
# Loss is  0.0475223919658499
# Loss TEST is  2117.251578393
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  16
# Loss is  0.02646632697126357
# Loss TEST is  1808.8359672993743
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  17
# Loss is  0.015401738103901334
# Loss TEST is  1549.7799277258052
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  18
# Loss is  0.010192616137336982
# Loss TEST is  1301.9626588520891
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  19
# Loss is  0.007213723180416638
# Loss TEST is  1091.277309276214
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  20
# Loss is  0.005728643270385188
# Loss TEST is  912.3241301309458
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  21
# Loss is  0.00475175135652244
# Loss TEST is  749.5897473402598
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  22
# Loss is  0.00398951506821501
# Loss TEST is  603.2270409455089
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  23
# Loss is  0.0034849748063759986
# Loss TEST is  495.6404903185144
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  24
# Loss is  0.003125360565696189
# Loss TEST is  423.90858817965943
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  25
# Loss is  0.002625787047612566
# Loss TEST is  362.33635542161636
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  26
# Loss is  0.002401087226655801
# Loss TEST is  298.049762423028
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  27
# Loss is  0.0021732123768588513
# Loss TEST is  245.84857467450513
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  28
# Loss is  0.002035349784153911
# Loss TEST is  207.44412897305514
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  29
# Loss is  0.002075972001119905
# Loss TEST is  178.39568556187206
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  30
# Loss is  0.0018114777150760575
# Loss TEST is  161.06092972635605
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  31
# Loss is  0.0017015862079170782
# Loss TEST is  159.55012092849006
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  32
# Loss is  0.001596977922152235
# Loss TEST is  151.2503880735503
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  33
# Loss is  0.0014900324956378637
# Loss TEST is  142.14683596622817
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  34
# Loss is  0.0014092639754458897
# Loss TEST is  136.69970085956587
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  35
# Loss is  0.001402320042698906
# Loss TEST is  132.185036317257
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  36
# Loss is  0.0012636387416617727
# Loss TEST is  124.46960035338552
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  37
# Loss is  0.0012462476526000652
# Loss TEST is  119.32627004981754
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  38
# Loss is  0.0011839063352702024
# Loss TEST is  121.8649077139673
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  39
# Loss is  0.0010537783579488904
# Loss TEST is  118.78186618849058
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  40
# Loss is  0.001095955414001012
# Loss TEST is  114.45089750286112
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  41
# Loss is  0.0009730671561744828
# Loss TEST is  106.83352527839043
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  42
# Loss is  0.0009593047844213482
# Loss TEST is  98.77241109536851
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [1. 1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  43
# Loss is  0.0008987244943931468
# Loss TEST is  92.61094767780098
#
# The accuracy in TEST is:
#   1    2    3
# [[0.   0.   0.  ]
#  [0.   0.16 0.  ]
#  [1.   0.84 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  44
# Loss is  0.0008626377439713156
# Loss TEST is  91.55325172524743
#
# The accuracy in TEST is:
#   1    2    3
# [[0.   0.   0.  ]
#  [0.   0.18 0.  ]
#  [1.   0.82 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  45
# Loss is  0.0008535785279717972
# Loss TEST is  93.69877015255722
#
# The accuracy in TEST is:
#   1    2    3
# [[0.   0.   0.  ]
#  [0.   0.09 0.  ]
#  [1.   0.91 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  46
# Loss is  0.0007803433984369263
# Loss TEST is  91.19430042901361
#
# The accuracy in TEST is:
#   1    2    3
# [[0.   0.   0.  ]
#  [0.   0.15 0.  ]
#  [1.   0.85 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  47
# Loss is  0.0008156177407866172
# Loss TEST is  80.62609401317911
#
# The accuracy in TEST is:
#   1    2    3
# [[0.   0.   0.  ]
#  [0.   0.24 0.  ]
#  [1.   0.76 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  48
# Loss is  0.0007772625828951344
# Loss TEST is  82.48387060176817
#
# The accuracy in TEST is:
#   1    2    3
# [[0.   0.   0.  ]
#  [0.   0.24 0.  ]
#  [1.   0.76 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Epoch:  49
# Loss is  0.0007024072519821104
# Loss TEST is  80.19308174659781
#
# The accuracy in TEST is:
#   1    2    3
# [[0.   0.   0.  ]
#  [0.   0.24 0.  ]
#  [1.   0.76 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# ----------------------
# Final Test error Net 60.31% 1512/2507
# 2173.614232301712

# %%
accuracyTEST = errorsTable()

model.eval()
lossValue = 0 
with torch.set_grad_enabled(False):
    for local_batch, local_labels in testing_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
        outputTest = model(local_batch)
        accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
        lossTest = criterion(outputTest, local_labels)
        lossValue += lossTest.item()*local_batch.size(0)
print('Loss TEST is ', lossValue/test_input.size(0))

print("")
print("The accuracy in TEST is: ")
print("  1    2    3  ")
print(accuracyTEST.getStats())
# Out:
# Loss TEST is  80.19308174659781
#
# The accuracy in TEST is:
#   1    2    3
# [[0.   0.   0.  ]
#  [0.   0.24 0.  ]
#  [1.   0.76 1.  ]]

# %%
plt.figure()
plt.plot(np.array(loss_test)/max(loss_test))
plt.plot(np.array(loss_train)/max(loss_train))

# %%
torch.save(model, './Models/model_adv_new')
