# %%
import torch
import torch.utils.data
import glob
import random
import numpy as np
import pandas as pd
from torch import nn, optim
from torch.nn import functional as F
import time
from torch.nn.utils import weight_norm

# %%
seed = 1995
random.seed(seed)     # python random generator
np.random.seed(seed)  # numpy random generator

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
Fs = 100000

# %%
train_data_torch = torch.load('./data torch/train_data_torch_newWet.pt')
train_targets_torch = torch.load('./data torch/train_targets_torch_newWet.pt')

test_data_torch = torch.load('./data torch/test_data_torch_newWet.pt')
test_targets_torch = torch.load('./data torch/test_targets_torch_newWet.pt')

# %%
test_targets_torch[test_targets_torch==2]=1
train_targets_torch[train_targets_torch==2]=1

# %%
print('Dim Train Data: ', train_data_torch.shape)
print('Dim Train Targets: ', train_targets_torch.shape)
print('Dim Test Data: ', test_data_torch.shape)
print('Dim Train Targets: ', test_targets_torch.shape)
# Out:
# Dim Train Data:  torch.Size([6984, 1, 35000])
# Dim Train Targets:  torch.Size([6984])
# Dim Test Data:  torch.Size([1749, 1, 35000])
# Dim Train Targets:  torch.Size([1749])

# %%
numChannels = 1
numClasses = 2

# %%
import matplotlib.pyplot as plt
i = 100

# %%
plt.plot(train_data_torch.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %% [markdown]
# # This is the formula for computing the size of the output of every layer
#
# $$L_{out} = \frac{L_{in}- Kernel_{size}}{stride}+1$$

# %% [markdown]
# # Here there's and example:
# $input size = 1 * 20'000 * 4 $
#
# after the first convolution:
# $output = \frac{20000-5000}{5}+1 = 3001$
# and the channels go from the initial 4 to the specified 32
#
# after the second convolution:
# $output = \frac{3001-2002}{1}+1 = 1000$
# and the channels go from 32 to 64
#
# after the last convolution:
# $output = \frac{1000-1000}{1}+1 = 1$
# and the channels go from 64 to 5 (as the number of classes!!!)

# %%
(35000-5000)/2+1
# Out:
# 15001.0

# %%
(15001-5000)/2+1
# Out:
# 5001.5

# %%
(5001-4500)/2+1
# Out:
# 251.5

# %%
class fastCNN(nn.Module): 
    def __init__(self):
        super(fastCNN, self).__init__()
        self.conv = nn.Conv1d(numChannels, 2, kernel_size=5000, stride=2) 
        self.bn = nn.BatchNorm1d(2) #15001
        self.conv2 = nn.Conv1d(2, 2, kernel_size=5000, stride=2)
        self.bn2 = nn.BatchNorm1d(2) #5001
        self.conv3 = nn.Conv1d(2, 2, kernel_size=4500, stride=2)
        self.bn3 = nn.BatchNorm1d(2) #251
        self.conv4 = nn.Conv1d(2, numClasses, kernel_size=251)
                
    def forward(self, x):
        x = F.relu(self.bn(self.conv(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.conv4(x)
        x = x.view(-1, numClasses)
        return x

# %%
# KERNEL_SIZE = 64
# POOL_FACT = 2
# STRIDE_FACT = KERNEL_SIZE // 4
# CHANNEL_COUNT = 16
# use_avg_pool = True
# model = torch.nn.Sequential() 
# output_dim = 35000
# model.append(torch.nn.Conv1d(in_channels = 1, out_channels = CHANNEL_COUNT, kernel_size = KERNEL_SIZE, stride=STRIDE_FACT)) #16x16896 - 512 + 1 
# output_dim = (output_dim - KERNEL_SIZE) // STRIDE_FACT + 1
# model.append(torch.nn.ReLU()) 
# if use_avg_pool:
#     model.append(torch.nn.AvgPool1d(POOL_FACT))
# else:
#     model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
# output_dim /= POOL_FACT
# model.append(torch.nn.Conv1d(in_channels = CHANNEL_COUNT, out_channels=CHANNEL_COUNT, kernel_size=KERNEL_SIZE // 2, stride=STRIDE_FACT // 2)) #16x7681
# output_dim = (output_dim - KERNEL_SIZE // 2) // (STRIDE_FACT // 2)+ 1
# model.append(torch.nn.ReLU())
# if use_avg_pool:
#     model.append(torch.nn.AvgPool1d(POOL_FACT))
# else:
#     model.append(torch.nn.MaxPool1d(POOL_FACT)) #16x8192
# output_dim /= POOL_FACT
# model.append(torch.nn.Flatten())
# model.append(torch.nn.Linear(in_features = int(output_dim) * CHANNEL_COUNT, out_features = 9))
# model.append(torch.nn.ReLU())
# model.append(torch.nn.Linear(in_features = 9, out_features = numClasses))

# %%
model, criterion = fastCNN(), nn.CrossEntropyLoss()

# %%
def count_parameters(model): return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
count_parameters(model)
# Out:
# 49024

# %%
def compute_nb_errors(model, testing_generator):
    nb_errors=0
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            predicted_classes = outputTest.max(1)[1]
            nb_errors += (predicted_classes != local_labels).long().sum()

    return nb_errors

# %%
#model, criterion = fastCNN(), nn.CrossEntropyLoss()

# %%
# criterion = nn.CrossEntropyLoss()

# %%
if (torch.cuda.is_available()):
    model = model.cuda()

# %%
train_input = train_data_torch.view(train_data_torch.size(0), numChannels, -1).float()
train_target = train_targets_torch.long().view(-1)
test_input = test_data_torch.view(test_data_torch.size(0), numChannels, -1).float()
test_target = test_targets_torch.long().view(-1)

# %%
train_input.shape
# Out:
# torch.Size([6984, 1, 35000])

# %%
# train_input = (train_input-torch.mean(train_input,2,keepdim=True))/1500.0#/(torch.max(train_input,2,keepdim=True)[0]-torch.min(train_input,2,keepdim=True)[0])
# test_input = (test_input-torch.mean(test_input,2,keepdim=True))/1500.0#/(torch.max(test_input,2,keepdim=True)[0]-torch.min(test_input,2,keepdim=True)[0])

# %%
train_input = train_input/4096.0#/(torch.max(train_input,2,keepdim=True)[0]-torch.min(train_input,2,keepdim=True)[0])
test_input = test_input/4096.0#/(torch.max(test_input,2,keepdim=True)[0]-torch.min(test_input,2,keepdim=True)[0])

# %%
plt.plot(train_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
plt.plot(test_input.narrow(0, i, 1).narrow(1, 0, 1).view(-1).numpy())

# %%
train_input.narrow(0, 0, 2).shape
# Out:
# torch.Size([2, 1, 35000])

# %%
out = model(train_input.narrow(0, 0, 2).cuda())
out.shape
# Out:
# torch.Size([2, 2])

# %%
lr = 3e-3

# %%
optimizer = optim.Adam(model.parameters(), lr = lr)
nb_epochs = 100
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', verbose=True, factor=0.2, patience = 30)

# %%
class errorsTable():
    def __init__(self):
        self.accuracyMatr = np.zeros((numClasses,numClasses))
    def newEntry(self,predictions,groundTruths):
        for pred,tru in zip(predictions,groundTruths):
            #print(pred, tru)
            self.accuracyMatr[pred,tru]+=1
    def getStats(self):
        #print(self.accuracyMatr)
        numEntry = np.sum(self.accuracyMatr,0)
        resultMatr = self.accuracyMatr/numEntry
        return resultMatr

# %%
np.set_printoptions(precision=2, suppress=True)

# %%
batch_size_train = 2000
batch_size_test = 1000

# %%
#torch.backends.cudnn.enabled = False

# %%
training_set = torch.utils.data.TensorDataset(train_input, train_target)
testing_set = torch.utils.data.TensorDataset(test_input, test_target)

# %%
# Generators
training_generator = torch.utils.data.DataLoader(training_set, batch_size=batch_size_train, num_workers=0,
                                                shuffle=True, drop_last=True)
testing_generator = torch.utils.data.DataLoader(testing_set, batch_size=batch_size_test, num_workers=0,
                                                 shuffle=False, drop_last=False)

# %%
loss_train = []
loss_test = []

t = time.time()
for k in range (nb_epochs):
    
    # Create a new error table
    accuracyTRAIN = errorsTable()
    accuracyTEST = errorsTable()
    print('Epoch: ', k)
    model.train()

    lossValue = 0
    for local_batch, local_labels in training_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()       
        model.zero_grad()
        output = model(local_batch)
        accuracyTRAIN.newEntry(output.max(1)[1], local_labels)
        loss = criterion(output, local_labels)
        lossValue += loss.item()*local_batch.size(0)
        loss.backward()
        optimizer.step()
    scheduler.step(lossValue/train_input.size(0))
    print('Loss is ', lossValue/train_input.size(0))
    loss_train.append(lossValue/train_input.size(0))    
    ################################################################    
    model.eval()
    lossValue = 0 
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in testing_generator:
            if (torch.cuda.is_available()):
                # Transfer to GPU
                local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
            outputTest = model(local_batch)
            accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
            lossTest = criterion(outputTest, local_labels)
            lossValue += lossTest.item()*local_batch.size(0)
    print('Loss TEST is ', lossValue/test_input.size(0))
    loss_test.append(lossValue/test_input.size(0))
    print("")
    print("The accuracy in TEST is: ")
    print("  1    2    3   ")
    print(accuracyTEST.getStats())
    print("The accuracy in TRAIN is: ")
    print("  1    2    3   ")
    print(accuracyTRAIN.getStats())
    print("----------------------")
    if k%10 == 0:
        #nb_test_errors = compute_nb_errors(model, test_input, test_target, batch_size_test)

        #print(k, ': Test accuracy Net {:0.2f}%% {:d}/{:d}'.format(100-(100 * nb_test_errors) / test_input.size(0),
                                                     #nb_test_errors, test_input.size(0)))
        

        #nb_train_errors = compute_nb_errors(model, train_input, train_target, batch_size_train)

        #print(k, ': Train accuracy Net {:0.2f}%% {:d}/{:d}'.format(100-(100 * nb_train_errors) / train_input.size(0),
                                                          #nb_train_errors, train_input.size(0)))
        print("Hey! Ten epochs are passed! We are getting older")
        
        


nb_test_errors = compute_nb_errors(model, testing_generator)  
print('Final Test error Net {:0.2f}% {:d}/{:d}'.format((100 * nb_test_errors) / test_input.size(0),
                                                  nb_test_errors, test_input.size(0)))

elapsed = time.time() - t
print(elapsed)
# Out:
# Epoch:  0
# Loss is  0.8131150766473182
# Loss TEST is  0.740714376776337
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.42 0.66]
#  [0.58 0.34]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  1
# Loss is  0.5912908437189232
# Loss TEST is  2.200628081589017
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.24 0.07]
#  [0.76 0.93]]
# ----------------------
# Epoch:  2
# Loss is  0.539348365788061
# Loss TEST is  2.82758331378981
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.51 0.12]
#  [0.49 0.88]]
# ----------------------
# Epoch:  3
# Loss is  0.4539583369082465
# Loss TEST is  6.266089342129752
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.74 0.3 ]
#  [0.26 0.7 ]]
# ----------------------
# Epoch:  4
# Loss is  0.3500567559250988
# Loss TEST is  12.237499753974928
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.74 0.01]
#  [0.26 0.99]]
# ----------------------
# Epoch:  5
# Loss is  0.2644449250531497
# Loss TEST is  23.204227663436026
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.74 0.02]
#  [0.26 0.98]]
# ----------------------
# Epoch:  6
# Loss is  0.17342058448857048
# Loss TEST is  41.89154841410493
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[0.87 0.03]
#  [0.13 0.97]]
# ----------------------
# Epoch:  7
# Loss is  0.08807043712436811
# Loss TEST is  63.90262645200159
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1.   0.03]
#  [0.   0.97]]
# ----------------------
# Epoch:  8
# Loss is  0.04511526364402126
# Loss TEST is  86.31299358562035
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1.   0.01]
#  [0.   0.99]]
# ----------------------
# Epoch:  9
# Loss is  0.028065780235320022
# Loss TEST is  109.81009795776158
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1.   0.01]
#  [0.   0.99]]
# ----------------------
# Epoch:  10
# Loss is  0.012388277397771609
# Loss TEST is  127.18677030010453
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  11
# Loss is  0.005443265207137439
# Loss TEST is  136.5497517135908
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  12
# Loss is  0.002974338263042809
# Loss TEST is  137.88787510273727
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  13
# Loss is  0.0017649186204346525
# Loss TEST is  132.59215052295508
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  14
# Loss is  0.0012693951361922532
# Loss TEST is  120.39445426683551
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  15
# Loss is  0.0011460801396083688
# Loss TEST is  104.82412941323614
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  16
# Loss is  0.000997161539911558
# Loss TEST is  88.79645092954902
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  17
# Loss is  0.0007071867919892909
# Loss TEST is  74.47204240872016
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  18
# Loss is  0.0005670766682734228
# Loss TEST is  62.654324025000896
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  19
# Loss is  0.0003890891093760729
# Loss TEST is  53.565520978505575
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  20
# Loss is  0.00033946162772995395
# Loss TEST is  46.60025891608821
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  21
# Loss is  0.0002702569527944117
# Loss TEST is  41.015136439572615
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  22
# Loss is  0.00023807950947542524
# Loss TEST is  36.20999850430715
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  23
# Loss is  0.00021335982269781375
# Loss TEST is  32.19835031639173
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  24
# Loss is  0.00017992749338556735
# Loss TEST is  28.978719651324194
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  25
# Loss is  0.00015768943739071368
# Loss TEST is  26.495260126322183
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  26
# Loss is  0.0001564726564125878
# Loss TEST is  24.521624312665274
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  27
# Loss is  0.00013348567268207354
# Loss TEST is  23.067526710994454
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  28
# Loss is  0.00011243753996384324
# Loss TEST is  20.273017774247116
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  29
# Loss is  0.00010618396482565349
# Loss TEST is  17.185168650710562
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  30
# Loss is  0.00010611302215530764
# Loss TEST is  14.574965863584994
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  31
# Loss is  0.00010170407104452608
# Loss TEST is  12.337547768995789
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  32
# Loss is  9.179228110258112e-05
# Loss TEST is  10.342577786497419
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  33
# Loss is  9.240154670682103e-05
# Loss TEST is  8.606202402000362
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  34
# Loss is  8.321261440269342e-05
# Loss TEST is  7.251791847713203
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  35
# Loss is  7.385807280214812e-05
# Loss TEST is  6.063937322966639
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  36
# Loss is  7.121880877272835e-05
# Loss TEST is  5.04448074419339
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  37
# Loss is  6.804973959713696e-05
# Loss TEST is  4.135270061460204
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  38
# Loss is  6.828877314050945e-05
# Loss TEST is  3.283668068765299
#
# The accuracy in TEST is:
#   1    2    3
# [[0. 0.]
#  [1. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  39
# Loss is  7.57853077022617e-05
# Loss TEST is  2.5580579584976686
#
# The accuracy in TEST is:
#   1    2    3
# [[0.08 0.  ]
#  [0.92 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  40
# Loss is  6.310744537453978e-05
# Loss TEST is  1.9849833938447048
#
# The accuracy in TEST is:
#   1    2    3
# [[0.23 0.  ]
#  [0.77 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  41
# Loss is  5.7424653692486755e-05
# Loss TEST is  1.5858546081033686
#
# The accuracy in TEST is:
#   1    2    3
# [[0.45 0.  ]
#  [0.55 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  42
# Loss is  5.9432351265906996e-05
# Loss TEST is  1.3281800170978035
#
# The accuracy in TEST is:
#   1    2    3
# [[0.49 0.  ]
#  [0.51 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  43
# Loss is  6.128326570455152e-05
# Loss TEST is  1.1541326882295253
#
# The accuracy in TEST is:
#   1    2    3
# [[0.52 0.  ]
#  [0.48 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  44
# Loss is  5.602995033904255e-05
# Loss TEST is  0.9672361820203368
#
# The accuracy in TEST is:
#   1    2    3
# [[0.52 0.  ]
#  [0.48 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  45
# Loss is  4.9791595954109275e-05
# Loss TEST is  0.8342549894249748
#
# The accuracy in TEST is:
#   1    2    3
# [[0.52 0.  ]
#  [0.48 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  46
# Loss is  5.198158731151752e-05
# Loss TEST is  0.7574613123637667
#
# The accuracy in TEST is:
#   1    2    3
# [[0.52 0.  ]
#  [0.48 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  47
# Loss is  4.511467207449607e-05
# Loss TEST is  0.6772909265984342
#
# The accuracy in TEST is:
#   1    2    3
# [[0.53 0.  ]
#  [0.47 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  48
# Loss is  4.6412450171268856e-05
# Loss TEST is  0.6110192953755689
#
# The accuracy in TEST is:
#   1    2    3
# [[0.54 0.  ]
#  [0.46 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  49
# Loss is  4.5651900072615134e-05
# Loss TEST is  0.521240162535773
#
# The accuracy in TEST is:
#   1    2    3
# [[0.59 0.  ]
#  [0.41 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  50
# Loss is  4.204456904918523e-05
# Loss TEST is  0.45284924839738333
#
# The accuracy in TEST is:
#   1    2    3
# [[0.65 0.  ]
#  [0.35 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  51
# Loss is  4.403721880877683e-05
# Loss TEST is  0.388383451020422
#
# The accuracy in TEST is:
#   1    2    3
# [[0.68 0.  ]
#  [0.32 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  52
# Loss is  4.5030282842734654e-05
# Loss TEST is  0.3136887383361587
#
# The accuracy in TEST is:
#   1    2    3
# [[0.72 0.  ]
#  [0.28 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  53
# Loss is  4.362584800016186e-05
# Loss TEST is  0.2472053686498262
#
# The accuracy in TEST is:
#   1    2    3
# [[0.76 0.  ]
#  [0.24 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  54
# Loss is  3.9440064802955206e-05
# Loss TEST is  0.20690228108796574
#
# The accuracy in TEST is:
#   1    2    3
# [[0.81 0.  ]
#  [0.19 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  55
# Loss is  4.117527234634461e-05
# Loss TEST is  0.18952747363132047
#
# The accuracy in TEST is:
#   1    2    3
# [[0.83 0.  ]
#  [0.17 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  56
# Loss is  3.716895651946512e-05
# Loss TEST is  0.16944336788815056
#
# The accuracy in TEST is:
#   1    2    3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  57
# Loss is  3.602617382217798e-05
# Loss TEST is  0.17053723771363674
#
# The accuracy in TEST is:
#   1    2    3
# [[0.84 0.  ]
#  [0.16 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  58
# Loss is  3.588693883030794e-05
# Loss TEST is  0.16218117627383805
#
# The accuracy in TEST is:
#   1    2    3
# [[0.85 0.  ]
#  [0.15 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  59
# Loss is  3.360193965608923e-05
# Loss TEST is  0.14467310625867524
#
# The accuracy in TEST is:
#   1    2    3
# [[0.85 0.  ]
#  [0.15 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  60
# Loss is  3.69388699869733e-05
# Loss TEST is  0.12352841318742398
#
# The accuracy in TEST is:
#   1    2    3
# [[0.86 0.  ]
#  [0.14 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  61
# Loss is  3.429503243895011e-05
# Loss TEST is  0.12047052301458444
#
# The accuracy in TEST is:
#   1    2    3
# [[0.86 0.  ]
#  [0.14 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  62
# Loss is  3.2088003422489405e-05
# Loss TEST is  0.12414510131333867
#
# The accuracy in TEST is:
#   1    2    3
# [[0.86 0.  ]
#  [0.14 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  63
# Loss is  3.3003066565477653e-05
# Loss TEST is  0.12518244344328863
#
# The accuracy in TEST is:
#   1    2    3
# [[0.86 0.  ]
#  [0.14 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  64
# Loss is  3.3115315713979974e-05
# Loss TEST is  0.11395662692253815
#
# The accuracy in TEST is:
#   1    2    3
# [[0.86 0.  ]
#  [0.14 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  65
# Loss is  3.1943807361009e-05
# Loss TEST is  0.09726877768491266
#
# The accuracy in TEST is:
#   1    2    3
# [[0.88 0.  ]
#  [0.12 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  66
# Loss is  3.177931227373628e-05
# Loss TEST is  0.07796135665491499
#
# The accuracy in TEST is:
#   1    2    3
# [[0.91 0.  ]
#  [0.09 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  67
# Loss is  2.8601022092869532e-05
# Loss TEST is  0.0627247826073842
#
# The accuracy in TEST is:
#   1    2    3
# [[0.93 0.  ]
#  [0.07 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  68
# Loss is  2.929275063367775e-05
# Loss TEST is  0.05307964156321795
#
# The accuracy in TEST is:
#   1    2    3
# [[0.95 0.  ]
#  [0.05 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  69
# Loss is  2.632392656304372e-05
# Loss TEST is  0.0469246043166297
#
# The accuracy in TEST is:
#   1    2    3
# [[0.96 0.  ]
#  [0.04 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  70
# Loss is  2.6551643512833156e-05
# Loss TEST is  0.04582883174324477
#
# The accuracy in TEST is:
#   1    2    3
# [[0.96 0.  ]
#  [0.04 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  71
# Loss is  2.6618913824847107e-05
# Loss TEST is  0.042730125577249256
#
# The accuracy in TEST is:
#   1    2    3
# [[0.96 0.  ]
#  [0.04 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  72
# Loss is  2.5600691792257247e-05
# Loss TEST is  0.036866430006721906
#
# The accuracy in TEST is:
#   1    2    3
# [[0.97 0.  ]
#  [0.03 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  73
# Loss is  2.5000264330402782e-05
# Loss TEST is  0.03343015198058634
#
# The accuracy in TEST is:
#   1    2    3
# [[0.98 0.  ]
#  [0.02 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  74
# Loss is  2.637498432460064e-05
# Loss TEST is  0.02698757359450376
#
# The accuracy in TEST is:
#   1    2    3
# [[0.98 0.  ]
#  [0.02 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  75
# Loss is  2.2755583483453216e-05
# Loss TEST is  0.02345217021529778
#
# The accuracy in TEST is:
#   1    2    3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  76
# Loss is  2.303887441419497e-05
# Loss TEST is  0.02362160401809387
#
# The accuracy in TEST is:
#   1    2    3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  77
# Loss is  2.5663176057696235e-05
# Loss TEST is  0.022340829379127566
#
# The accuracy in TEST is:
#   1    2    3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  78
# Loss is  2.4627305348135716e-05
# Loss TEST is  0.018525191814159018
#
# The accuracy in TEST is:
#   1    2    3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  79
# Loss is  2.156103876525246e-05
# Loss TEST is  0.017114152910851065
#
# The accuracy in TEST is:
#   1    2    3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  80
# Loss is  2.0486920834341612e-05
# Loss TEST is  0.014776089995600473
#
# The accuracy in TEST is:
#   1    2    3
# [[0.99 0.  ]
#  [0.01 1.  ]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  81
# Loss is  2.3969986544446464e-05
# Loss TEST is  0.011925933594915773
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  82
# Loss is  2.3242053759504612e-05
# Loss TEST is  0.009191196220550627
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  83
# Loss is  2.0468954928119304e-05
# Loss TEST is  0.009292771473336063
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  84
# Loss is  2.1185021047081153e-05
# Loss TEST is  0.009299522696499255
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  85
# Loss is  1.990219179277771e-05
# Loss TEST is  0.008804234062433837
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  86
# Loss is  1.958517559000183e-05
# Loss TEST is  0.008599406939477926
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  87
# Loss is  1.9744427799741137e-05
# Loss TEST is  0.008271017909579379
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  88
# Loss is  1.9588335901774833e-05
# Loss TEST is  0.007690266647208411
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  89
# Loss is  1.8537664285882024e-05
# Loss TEST is  0.007871538498702485
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  90
# Loss is  1.9470966287683493e-05
# Loss TEST is  0.007685025030512172
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Hey! Ten epochs are passed! We are getting older
# Epoch:  91
# Loss is  2.0081560191745577e-05
# Loss TEST is  0.0058575103073419815
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  92
# Loss is  1.9150970005188915e-05
# Loss TEST is  0.005417392097684635
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  93
# Loss is  1.740331499021098e-05
# Loss TEST is  0.004501737917253829
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  94
# Loss is  1.753862706993953e-05
# Loss TEST is  0.003918163963489673
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  95
# Loss is  1.73391950928341e-05
# Loss TEST is  0.003445081983747265
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  96
# Loss is  1.9802491170830785e-05
# Loss TEST is  0.0033180474886758344
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  97
# Loss is  1.9066636509929846e-05
# Loss TEST is  0.0032897652960242768
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  98
# Loss is  1.720907275864608e-05
# Loss TEST is  0.002930143356217721
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Epoch:  99
# Loss is  1.624234083618271e-05
# Loss TEST is  0.0029434229774471877
#
# The accuracy in TEST is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# The accuracy in TRAIN is:
#   1    2    3
# [[1. 0.]
#  [0. 1.]]
# ----------------------
# Final Test error Net 0.00% 0/1749
# 2661.4131104946136

# %%
accuracyTEST = errorsTable()

model.eval()
lossValue = 0 
with torch.set_grad_enabled(False):
    for local_batch, local_labels in testing_generator:
        if (torch.cuda.is_available()):
            # Transfer to GPU
            local_batch, local_labels = local_batch.cuda(), local_labels.cuda()
        outputTest = model(local_batch)
        accuracyTEST.newEntry(outputTest.max(1)[1], local_labels)
        lossTest = criterion(outputTest, local_labels)
        lossValue += lossTest.item()*local_batch.size(0)
print('Loss TEST is ', lossValue/test_input.size(0))

print("")
print("The accuracy in TEST is: ")
print("  1       2")
print(accuracyTEST.getStats())
# Out:
# Loss TEST is  0.0029434229774471877
#
# The accuracy in TEST is:
#   1       2
# [[1. 0.]
#  [0. 1.]]

# %%
plt.figure()
plt.plot(np.array(loss_test)/max(loss_test))
plt.plot(np.array(loss_train)/max(loss_train))

# %%
torch.save(model, './Models/model_wet_new')
