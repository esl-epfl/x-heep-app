# %%
import torch
import glob
import numpy as np
import pandas as pd
from torch import nn, optim
from torch.nn import functional as F
import time 
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
winLen = 35000

# %%
def data_loader(path):  
    allFiles = glob.glob(path + "/*.csv")
    fileNum = 0
    dataTorch = []
    for file_ in allFiles:
        # print(file_)
        singleFile = torch.from_numpy(pd.read_csv(file_, index_col=0, header=None)
                                      .reset_index().values).view(-1,1,winLen)
        dataTorch.append(singleFile) 
        fileNum += 1
        print('File number: ', fileNum, ' out of', len(allFiles), 'finished', 'shape :', singleFile.shape)
    return dataTorch

# %%
def load_plot_save(path):
    data = data_loader(path)
    for i in range(len(data)):
        print("Shape of the data {} : ".format(i))
        print(data[i].shape)


#         plt.figure()
#         plt.plot(data[i].narrow(0,0,1).view(-1), label='First window part {}'.format(i))
#         plt.legend()
#         plt.show()
        
#         plt.figure()
#         plt.plot(data[i].narrow(0,data[i].size(0)-1,1).view(-1), label='Last window part {}'.format(i))
#         plt.legend()
#         plt.show()


    data_cat = torch.cat(data, 0)
    print('Data_cat: ', data_cat.shape)


#     plt.figure()
#     plt.plot(data_cat.narrow(0,0,1).view(-1).numpy(), label='First window')
#     plt.legend()
#     plt.show()

#     plt.figure()
#     plt.plot(data_cat.narrow(0,data_cat.size(0)-1,1).view(-1).numpy(), label='Last window')
#     plt.legend()
#     plt.show()
    
    torch.save(data_cat, './main torch/'+path.split('/')[-2])

# %% [markdown]
# # Give me the PATH of the FIRST Category

# %%
path = "./main raw/S11_dry/"
load_plot_save(path)
# Out:
# File number:  1  out of 4 finished shape : torch.Size([251, 1, 35000])
# File number:  2  out of 4 finished shape : torch.Size([226, 1, 35000])
# File number:  3  out of 4 finished shape : torch.Size([301, 1, 35000])
# File number:  4  out of 4 finished shape : torch.Size([301, 1, 35000])
# Shape of the data 0 :
# torch.Size([251, 1, 35000])
# Shape of the data 1 :
# torch.Size([226, 1, 35000])
# Shape of the data 2 :
# torch.Size([301, 1, 35000])
# Shape of the data 3 :
# torch.Size([301, 1, 35000])
# Data_cat:  torch.Size([1079, 1, 35000])

# %%
path = "./main raw/S12_dry/"
load_plot_save(path)
# Out:
# File number:  1  out of 5 finished shape : torch.Size([301, 1, 35000])
# File number:  2  out of 5 finished shape : torch.Size([111, 1, 35000])
# File number:  3  out of 5 finished shape : torch.Size([327, 1, 35000])
# File number:  4  out of 5 finished shape : torch.Size([199, 1, 35000])
# File number:  5  out of 5 finished shape : torch.Size([227, 1, 35000])
# Shape of the data 0 :
# torch.Size([301, 1, 35000])
# Shape of the data 1 :
# torch.Size([111, 1, 35000])
# Shape of the data 2 :
# torch.Size([327, 1, 35000])
# Shape of the data 3 :
# torch.Size([199, 1, 35000])
# Shape of the data 4 :
# torch.Size([227, 1, 35000])
# Data_cat:  torch.Size([1165, 1, 35000])

# %%
path = "./main raw/S13_dry/"
load_plot_save(path)
# Out:
# File number:  1  out of 4 finished shape : torch.Size([329, 1, 35000])
# File number:  2  out of 4 finished shape : torch.Size([259, 1, 35000])
# File number:  3  out of 4 finished shape : torch.Size([110, 1, 35000])
# File number:  4  out of 4 finished shape : torch.Size([218, 1, 35000])
# Shape of the data 0 :
# torch.Size([329, 1, 35000])
# Shape of the data 1 :
# torch.Size([259, 1, 35000])
# Shape of the data 2 :
# torch.Size([110, 1, 35000])
# Shape of the data 3 :
# torch.Size([218, 1, 35000])
# Data_cat:  torch.Size([916, 1, 35000])

# %%
path = "./main raw/S14_dry/"
load_plot_save(path)
# Out:
# File number:  1  out of 5 finished shape : torch.Size([235, 1, 35000])
# File number:  2  out of 5 finished shape : torch.Size([277, 1, 35000])
# File number:  3  out of 5 finished shape : torch.Size([236, 1, 35000])
# File number:  4  out of 5 finished shape : torch.Size([82, 1, 35000])
# File number:  5  out of 5 finished shape : torch.Size([181, 1, 35000])
# Shape of the data 0 :
# torch.Size([235, 1, 35000])
# Shape of the data 1 :
# torch.Size([277, 1, 35000])
# Shape of the data 2 :
# torch.Size([236, 1, 35000])
# Shape of the data 3 :
# torch.Size([82, 1, 35000])
# Shape of the data 4 :
# torch.Size([181, 1, 35000])
# Data_cat:  torch.Size([1011, 1, 35000])

# %% [markdown]
# # Give me the PATH of the SECOND Category

# %%
path = "./main raw/S21_demi/"
load_plot_save(path)

# %%
path = "./main raw/S22_demi/"
load_plot_save(path)

# %%
path = "./main raw/S23_demi/"
load_plot_save(path)

# %%
path = "./main raw/S24_demi/"
load_plot_save(path)

# %% [markdown]
# # Give me the PATH of the THIRD Category

# %%
path = "./main raw/S31_wet/"
load_plot_save(path)
# Out:
# File number:  1  out of 5 finished shape : torch.Size([262, 1, 35000])
# File number:  2  out of 5 finished shape : torch.Size([173, 1, 35000])
# File number:  3  out of 5 finished shape : torch.Size([261, 1, 35000])
# File number:  4  out of 5 finished shape : torch.Size([231, 1, 35000])
# File number:  5  out of 5 finished shape : torch.Size([225, 1, 35000])
# Shape of the data 0 :
# torch.Size([262, 1, 35000])
# Shape of the data 1 :
# torch.Size([173, 1, 35000])
# Shape of the data 2 :
# torch.Size([261, 1, 35000])
# Shape of the data 3 :
# torch.Size([231, 1, 35000])
# Shape of the data 4 :
# torch.Size([225, 1, 35000])
# Data_cat:  torch.Size([1152, 1, 35000])

# %%
path = "./main raw/S32_wet/"
load_plot_save(path)
# Out:
# File number:  1  out of 5 finished shape : torch.Size([119, 1, 35000])
# File number:  2  out of 5 finished shape : torch.Size([286, 1, 35000])
# File number:  3  out of 5 finished shape : torch.Size([339, 1, 35000])
# File number:  4  out of 5 finished shape : torch.Size([167, 1, 35000])
# File number:  5  out of 5 finished shape : torch.Size([314, 1, 35000])
# Shape of the data 0 :
# torch.Size([119, 1, 35000])
# Shape of the data 1 :
# torch.Size([286, 1, 35000])
# Shape of the data 2 :
# torch.Size([339, 1, 35000])
# Shape of the data 3 :
# torch.Size([167, 1, 35000])
# Shape of the data 4 :
# torch.Size([314, 1, 35000])
# Data_cat:  torch.Size([1225, 1, 35000])

# %%
path = "./main raw/S33_wet/"
load_plot_save(path)
# Out:
# File number:  1  out of 4 finished shape : torch.Size([301, 1, 35000])
# File number:  2  out of 4 finished shape : torch.Size([286, 1, 35000])
# File number:  3  out of 4 finished shape : torch.Size([315, 1, 35000])
# File number:  4  out of 4 finished shape : torch.Size([283, 1, 35000])
# Shape of the data 0 :
# torch.Size([301, 1, 35000])
# Shape of the data 1 :
# torch.Size([286, 1, 35000])
# Shape of the data 2 :
# torch.Size([315, 1, 35000])
# Shape of the data 3 :
# torch.Size([283, 1, 35000])
# Data_cat:  torch.Size([1185, 1, 35000])

# %%
path = "./main raw/S34_wet/"
load_plot_save(path)
# Out:
# File number:  1  out of 4 finished shape : torch.Size([244, 1, 35000])
# File number:  2  out of 4 finished shape : torch.Size([263, 1, 35000])
# File number:  3  out of 4 finished shape : torch.Size([274, 1, 35000])
# File number:  4  out of 4 finished shape : torch.Size([219, 1, 35000])
# Shape of the data 0 :
# torch.Size([244, 1, 35000])
# Shape of the data 1 :
# torch.Size([263, 1, 35000])
# Shape of the data 2 :
# torch.Size([274, 1, 35000])
# Shape of the data 3 :
# torch.Size([219, 1, 35000])
# Data_cat:  torch.Size([1000, 1, 35000])

# %%
def plot_mean(sample):
    data_final = torch.load('./main torch/'+sample)
    print("Data shape: ", data_final.shape)
    ending_wind = data_final.narrow(2,32000, 3000)
    mean_wind = torch.mean(ending_wind.float(), 2).view(-1)
    plt.figure()
    plt.plot(mean_wind)
    plt.title(sample)

# %%
def plot_windows(sample, index):
    data_final = torch.load('./main torch/'+sample)
    print("Data shape: ", data_final.shape)
    plt.figure()
    for i in range(10):
        plt.plot(data_final.narrow(0,index+i,1).view(-1), label='Window {}'.format(index+i))
    plt.legend()
    plt.title(sample)

# %%
sample = 'S11_dry'
plot_mean(sample)
# Out:
# Data shape:  torch.Size([1079, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S11_dry'
index = 775
plot_windows(sample, index)
# Out:
# Data shape:  torch.Size([1079, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S12_dry'
plot_mean(sample)
# Out:
# Data shape:  torch.Size([1165, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S13_dry'
plot_mean(sample)
# Out:
# Data shape:  torch.Size([916, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S14_dry'
plot_mean(sample)
# Out:
# Data shape:  torch.Size([1011, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S14_dry'
index = 145
plot_windows(sample, index)
# Out:
# Data shape:  torch.Size([1011, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S21_dry'
plot_mean(sample)

# %%
sample = 'S22_dry'
plot_mean(sample)

# %%
sample = 'S22_dry'
index = 700
plot_windows(sample, index)

# %%
sample = 'S23_dry'
plot_mean(sample)

# %%
sample = 'S24_dry'
plot_mean(sample)

# %%
sample = 'S24_dry'
index = 4
plot_windows(sample, index)

# %%
sample = 'S31_wet'
plot_mean(sample)
# Out:
# Data shape:  torch.Size([1152, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S31_wet'
index = 518
plot_windows(sample, index)
# Out:
# Data shape:  torch.Size([1152, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S32_wet'
plot_mean(sample)
# Out:
# Data shape:  torch.Size([1225, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S32_wet'
index = 599
plot_windows(sample, index)
# Out:
# Data shape:  torch.Size([1225, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S33_wet'
plot_mean(sample)
# Out:
# Data shape:  torch.Size([1185, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S34_wet'
plot_mean(sample)
# Out:
# Data shape:  torch.Size([1000, 1, 35000])
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 'S34_wet'
index = 599
plot_windows(sample, index)
# Out:
# Data shape:  torch.Size([1000, 1, 35000])
# <img src="data:image/png;base64,..." width="640">
